# %%
import pandas as pd

# %%
final_df = pd.read_csv('final_15.csv')
df = pd.read_csv('min_15_start_1500_end_1515_.csv')
df2 = pd.read_csv('new_extracted_data_chavez_time_15.csv')
df4 = pd.read_csv('pro_players_15min')
df5 = pd.read_csv('new_extracted_data_Jared_time_15.csv')
df6 = pd.read_csv('new_extracted_data_smith_time_15.csv')
df7 = pd.read_csv('new_extracted_data_bryant_time_15.csv')

# %%
#df = pd.concat([df, df2], axis=0, ignore_index=True)

# %%
#df = pd.concat([df, df3], axis=0, ignore_index=True)

# %%
#df = pd.concat([df, df4], axis=0, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-bb962294209b> in <module>
# ----> 1 df = pd.concat([df, df4], axis=0, ignore_index=True)
#
# NameError: name 'df4' is not defined

# %%
df = pd.concat([final_df, df5], axis=0, ignore_index=True)

# %%
df = pd.concat([df, df6], axis=0, ignore_index=True)

# %%
new_extracted_data_bryant_time_15.csv

# %%
df = pd.concat([df, df6], axis=0, ignore_index=True)

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.to_csv('final_15.csv')

# %%
df
# Out:
#       airdragon_team100  assistsplayer_1  assistsplayer_10  assistsplayer_2  \
# 0                   0.0              2.0               5.0              0.0
# 1                   0.0              1.0               4.0              3.0
# 2                   0.0              1.0               5.0              1.0
# 3                   0.0              3.0               4.0              6.0
# 4                   0.0              0.0               5.0              1.0
# ...                 ...              ...               ...              ...
# 5246                0.0              5.0               4.0              1.0
# 5247                0.0              0.0               3.0              2.0
# 5248                0.0              1.0               6.0              0.0
# 5249                0.0              0.0               4.0              0.0
# 5250                2.0              3.0               2.0              0.0
#
# ...
