# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from sklearn.model_selection import train_test_split
import re
from acquire import extract, build_prepared_df, get_new_patch_data, get_players
from prepare import prepare
from env import api_key

# %%
players = get_players(1500, 1515)

# %%
len(players)
# Out:
# 15

# %%
#get_new_patch_data(players, api_key)
# Out:
# Beginning Loop for user Tencent is gay
# 	-Got the puuid for user Tencent is gay.
# 	-Created timeline_data_user_Tencent is gay_end_0.json
# 	-Created other_game_data_user_Tencent is gay_end_0.json
#
# 	-Completed getting all current patch Match IDs for user Tencent is gay
# 	-There are 14 users left.
# 	-Completed 8 Match IDs for user Tencent is gay
#
# Beginning Loop for user RipperJ98
# 	-Got the puuid for user RipperJ98.
# 	-Completed getting all current patch Match IDs for user RipperJ98
# 	-There are 13 users left.
# 	-Completed 12 Match IDs for user RipperJ98
#
# Beginning Loop for user Kycaxisha
# 	-Got the puuid for user Kycaxisha.
# 	-Completed getting all current patch Match IDs for user Kycaxisha
# 	-There are 12 users left.
# 	-Completed 0 Match IDs for user Kycaxisha
#
# Beginning Loop for user xBlotter
# 	-Got the puuid for user xBlotter.
# 	-Completed getting all current patch Match IDs for user xBlotter
# 	-There are 11 users left.
# ...

# %%
df = build_prepared_df(path = './', time = 10)
# Out:
# Done! now lets get some korean bbq, more chicken plz! haha....follow suit
# Finished with: 0 of 95
# Skipping: 1 due to <15 min or not classic
# Skipping: 2 due to <15 min or not classic
# Skipping: 3 due to <15 min or not classic
# Skipping: 4 due to <15 min or not classic
# Skipping: 5 due to <15 min or not classic
# Finished with: 6 of 95
# Finished with: 7 of 95
# Skipping: 8 due to <15 min or not classic
# Skipping: 9 due to <15 min or not classic
# Skipping: 10 due to <15 min or not classic
# Skipping: 11 due to <15 min or not classic
# Skipping: 12 due to <15 min or not classic
# Skipping: 13 due to <15 min or not classic
# Skipping: 14 due to <15 min or not classic
# Skipping: 15 due to <15 min or not classic
# Skipping: 16 due to <15 min or not classic
# Skipping: 17 due to <15 min or not classic
# Skipping: 18 due to <15 min or not classic
# Skipping: 19 due to <15 min or not classic
# Finished with: 20 of 95
# Finished with: 21 of 95
# ...

# %%
df.to_csv('min_10_start_1500_end_1515_.csv')
