# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from sklearn.model_selection import train_test_split
import re
from acquire import extract, build_prepared_df, get_new_patch_data, get_players
from prepare import prepare
from env import api_key

# %%
players = get_players(2132, 2500)

# %%
len(players)
# Out:
# 368

# %%
get_new_patch_data(players, api_key)
# Out:
# Beginning Loop for user Spokna
# 	-Got the puuid for user Spokna.
# 	-Created timeline_data_user_Spokna_end_0.json
# 	-Created other_game_data_user_Spokna_end_0.json
#
# 	-Completed getting all current patch Match IDs for user Spokna
# 	-There are 367 users left.
# 	-Completed 3 Match IDs for user Spokna
#
# Beginning Loop for user ElijahDD
# 	-Got the puuid for user ElijahDD.
# 	-Completed getting all current patch Match IDs for user ElijahDD
# 	-There are 366 users left.
# 	-Completed 2 Match IDs for user ElijahDD
#
# Beginning Loop for user Pr0Dark
# 	-Got the puuid for user Pr0Dark.
# 	-Completed getting all current patch Match IDs for user Pr0Dark
# 	-There are 365 users left.
# 	-Completed 3 Match IDs for user Pr0Dark
#
# Beginning Loop for user Meister Chief
# 	-Got the puuid for user Meister Chief.
# 	-Completed getting all current patch Match IDs for user Meister Chief
# 	-There are 364 users left.
# 	-Completed 1 Match IDs for user Meister Chief
#
# Beginning Loop for user AlphaMaleMelvin
# 	-Got the puuid for user AlphaMaleMelvin.
# 	-Completed getting all current patch Match IDs for user AlphaMaleMelvin
# 	-There are 363 users left.
# 	-Completed 3 Match IDs for user AlphaMaleMelvin
#
# Beginning Loop for user Yi Kuai Shao Rou
# 	-Got the puuid for user Yi Kuai Shao Rou.
# 	-Completed getting all current patch Match IDs for user Yi Kuai Shao Rou
# 	-There are 362 users left.
# 	-Completed 0 Match IDs for user Yi Kuai Shao Rou
#
# Beginning Loop for user MAMMOTHMAN65
# 	-Got the puuid for user MAMMOTHMAN65.
# 	-Completed getting all current patch Match IDs for user MAMMOTHMAN65
# 	-There are 361 users left.
# 	-Completed 0 Match IDs for user MAMMOTHMAN65
#
# Beginning Loop for user BE Hunter
# 	-Got the puuid for user BE Hunter.
# 	-Completed getting all current patch Match IDs for user BE Hunter
# 	-There are 360 users left.
# 	-Completed 0 Match IDs for user BE Hunter
#
# Beginning Loop for user 1982657489
# 	-Got the puuid for user 1982657489.
# 	-Completed getting all current patch Match IDs for user 1982657489
# 	-There are 359 users left.
# 	-Completed 8 Match IDs for user 1982657489
#
# Beginning Loop for user Xakutara
# 	-Got the puuid for user Xakutara.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user Xakutara
# 	-There are 358 users left.
# 	-Completed 10 Match IDs for user Xakutara
#
# Beginning Loop for user Kriffi
# 	-Got the puuid for user Kriffi.
# 	-Completed getting all current patch Match IDs for user Kriffi
# 	-There are 357 users left.
# 	-Completed 5 Match IDs for user Kriffi
#
# Beginning Loop for user xReaperXMichaelx
# 	-Got the puuid for user xReaperXMichaelx.
# 	-Completed getting all current patch Match IDs for user xReaperXMichaelx
# 	-There are 356 users left.
# 	-Completed 21 Match IDs for user xReaperXMichaelx
#
# Beginning Loop for user FluffyDoom1
# 	-Got the puuid for user FluffyDoom1.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user FluffyDoom1
# 	-There are 355 users left.
# 	-Completed 3 Match IDs for user FluffyDoom1
#
# Beginning Loop for user Lhulmari
# 	-Got the puuid for user Lhulmari.
# 	-Completed getting all current patch Match IDs for user Lhulmari
# 	-There are 354 users left.
# 	-Completed 3 Match IDs for user Lhulmari
#
# Beginning Loop for user SloppyThirds
# 	-Got the puuid for user SloppyThirds.
# 	-Completed getting all current patch Match IDs for user SloppyThirds
# 	-There are 353 users left.
# 	-Completed 0 Match IDs for user SloppyThirds
#
# Beginning Loop for user izuyui
# 	-Got the puuid for user izuyui.
# 	-Completed getting all current patch Match IDs for user izuyui
# 	-There are 352 users left.
# 	-Completed 0 Match IDs for user izuyui
#
# Beginning Loop for user AutoSwolekus
# 	-Got the puuid for user AutoSwolekus.
# 	-Completed getting all current patch Match IDs for user AutoSwolekus
# 	-There are 351 users left.
# 	-Completed 4 Match IDs for user AutoSwolekus
#
# Beginning Loop for user Vortekxy
# 	-Got the puuid for user Vortekxy.
# 	-Completed getting all current patch Match IDs for user Vortekxy
# 	-There are 350 users left.
# 	-Completed 8 Match IDs for user Vortekxy
#
# Beginning Loop for user Nimdle
# 	-Got the puuid for user Nimdle.
# 	-Completed getting all current patch Match IDs for user Nimdle
# 	-There are 349 users left.
# 	-Completed 2 Match IDs for user Nimdle
#
# Beginning Loop for user CateCoin TO MOON
# 	-Got the puuid for user CateCoin TO MOON.
# 	-Completed getting all current patch Match IDs for user CateCoin TO MOON
# 	-There are 348 users left.
# 	-Completed 1 Match IDs for user CateCoin TO MOON
#
# Beginning Loop for user Zakn7
# 	-Got the puuid for user Zakn7.
# 	-Completed getting all current patch Match IDs for user Zakn7
# 	-There are 347 users left.
# 	-Completed 6 Match IDs for user Zakn7
#
# Beginning Loop for user Hayai SingedSama
# 	-Got the puuid for user Hayai SingedSama.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user Hayai SingedSama
# 	-There are 346 users left.
# 	-Completed 8 Match IDs for user Hayai SingedSama
#
# Beginning Loop for user chu love
# 	-Got the puuid for user chu love.
# 	-Completed getting all current patch Match IDs for user chu love
# 	-There are 345 users left.
# 	-Completed 19 Match IDs for user chu love
#
# Beginning Loop for user Amate
# 	-Got the puuid for user Amate.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user Amate
# 	-There are 344 users left.
# 	-Completed 8 Match IDs for user Amate
#
# Beginning Loop for user Xehru
# 	-Got the puuid for user Xehru.
# 	-Completed getting all current patch Match IDs for user Xehru
# 	-There are 343 users left.
# 	-Completed 6 Match IDs for user Xehru
#
# Beginning Loop for user chuzday
# 	-Got the puuid for user chuzday.
# 	-Completed getting all current patch Match IDs for user chuzday
# 	-There are 342 users left.
# 	-Completed 5 Match IDs for user chuzday
#
# Beginning Loop for user Barry Buggles
# 	-Got the puuid for user Barry Buggles.
# 	-Completed getting all current patch Match IDs for user Barry Buggles
# 	-There are 341 users left.
# 	-Completed 8 Match IDs for user Barry Buggles
#
# Beginning Loop for user Daizzi
# 	-Got the puuid for user Daizzi.
# 	-Completed getting all current patch Match IDs for user Daizzi
# 	-There are 340 users left.
# 	-Completed 0 Match IDs for user Daizzi
#
# Beginning Loop for user Hide on 7SHAI
# 	-Got the puuid for user Hide on 7SHAI.
# 	-Completed getting all current patch Match IDs for user Hide on 7SHAI
# 	-There are 339 users left.
# 	-Completed 4 Match IDs for user Hide on 7SHAI
#
# Beginning Loop for user KingAone
# 	-Got the puuid for user KingAone.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user KingAone
# 	-There are 338 users left.
# 	-Completed 10 Match IDs for user KingAone
#
# Beginning Loop for user Contrail
# 	-Got the puuid for user Contrail.
# 	-Completed getting all current patch Match IDs for user Contrail
# 	-There are 337 users left.
# 	-Completed 1 Match IDs for user Contrail
#
# Beginning Loop for user Kill1ingGod
# 	-Got the puuid for user Kill1ingGod.
# 	-Completed getting all current patch Match IDs for user Kill1ingGod
# 	-There are 336 users left.
# 	-Completed 3 Match IDs for user Kill1ingGod
#
# Beginning Loop for user yfinmO
# 	-Got the puuid for user yfinmO.
# 	-Completed getting all current patch Match IDs for user yfinmO
# 	-There are 335 users left.
# 	-Completed 3 Match IDs for user yfinmO
#
# Beginning Loop for user LDCs
# 	-Got the puuid for user LDCs.
# 	-Completed getting all current patch Match IDs for user LDCs
# 	-There are 334 users left.
# 	-Completed 0 Match IDs for user LDCs
#
# Beginning Loop for user 5j341klk4j23gdfg
# 	-Got the puuid for user 5j341klk4j23gdfg.
# 	-Completed getting all current patch Match IDs for user 5j341klk4j23gdfg
# 	-There are 333 users left.
# 	-Completed 3 Match IDs for user 5j341klk4j23gdfg
#
# Beginning Loop for user Fiction
# 	-Got the puuid for user Fiction.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user Fiction
# 	-There are 332 users left.
# 	-Completed 20 Match IDs for user Fiction
#
# Beginning Loop for user ShadowyFigure
# 	-Got the puuid for user ShadowyFigure.
# 	-Completed getting all current patch Match IDs for user ShadowyFigure
# 	-There are 331 users left.
# 	-Completed 0 Match IDs for user ShadowyFigure
#
# Beginning Loop for user Raion23412
# 	-Got the puuid for user Raion23412.
# 	-Completed getting all current patch Match IDs for user Raion23412
# 	-There are 330 users left.
# 	-Completed 0 Match IDs for user Raion23412
#
# Beginning Loop for user Roffamau2
# 	-Got the puuid for user Roffamau2.
# 	-Completed getting all current patch Match IDs for user Roffamau2
# 	-There are 329 users left.
# 	-Completed 2 Match IDs for user Roffamau2
#
# Beginning Loop for user DU 4 LQVE
# 	-Got the puuid for user DU 4 LQVE.
# 	-Completed getting all current patch Match IDs for user DU 4 LQVE
# 	-There are 328 users left.
# 	-Completed 0 Match IDs for user DU 4 LQVE
#
# Beginning Loop for user Tippey
# 	-Got the puuid for user Tippey.
# 	-Completed getting all current patch Match IDs for user Tippey
# 	-There are 327 users left.
# 	-Completed 15 Match IDs for user Tippey
#
# Beginning Loop for user destiny9
# 	-Got the puuid for user destiny9.
# 	-Completed getting all current patch Match IDs for user destiny9
# 	-There are 326 users left.
# 	-Completed 0 Match IDs for user destiny9
#
# Beginning Loop for user rain take you
# 	-Got the puuid for user rain take you.
# 	-Completed getting all current patch Match IDs for user rain take you
# 	-There are 325 users left.
# 	-Completed 0 Match IDs for user rain take you
#
# Beginning Loop for user ScaleneCircle
# 	-Got the puuid for user ScaleneCircle.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user ScaleneCircle
# 	-There are 324 users left.
# 	-Completed 7 Match IDs for user ScaleneCircle
#
# Beginning Loop for user Cant but I will
# 	-Got the puuid for user Cant but I will.
# 	-Completed getting all current patch Match IDs for user Cant but I will
# 	-There are 323 users left.
# 	-Completed 12 Match IDs for user Cant but I will
#
# Beginning Loop for user FirstTimeCaitlyn
# 	-Got the puuid for user FirstTimeCaitlyn.
# 	-Completed getting all current patch Match IDs for user FirstTimeCaitlyn
# 	-There are 322 users left.
# 	-Completed 17 Match IDs for user FirstTimeCaitlyn
#
# Beginning Loop for user Mr Zlatan
# 	-Got the puuid for user Mr Zlatan.
# 	-Completed getting all current patch Match IDs for user Mr Zlatan
# 	-There are 321 users left.
# 	-Completed 0 Match IDs for user Mr Zlatan
#
# Beginning Loop for user For Lalisa
# 	-Got the puuid for user For Lalisa.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user For Lalisa
# 	-There are 320 users left.
# 	-Completed 2 Match IDs for user For Lalisa
#
# Beginning Loop for user ChannyBoyy
# 	-Got the puuid for user ChannyBoyy.
# 	-Completed getting all current patch Match IDs for user ChannyBoyy
# 	-There are 319 users left.
# 	-Completed 2 Match IDs for user ChannyBoyy
#
# Beginning Loop for user LazarusJungle
# Something went wrong! Status Code: 404. Did not get puuid for user: LazarusJungle
# Skipping this user. There are 318 users left.
#
# Beginning Loop for user Fullscreened
# 	-Got the puuid for user Fullscreened.
# 	-Completed getting all current patch Match IDs for user Fullscreened
# 	-There are 317 users left.
# 	-Completed 0 Match IDs for user Fullscreened
#
# Beginning Loop for user ThePieCrusader
# 	-Got the puuid for user ThePieCrusader.
# 	-Completed getting all current patch Match IDs for user ThePieCrusader
# 	-There are 316 users left.
# 	-Completed 0 Match IDs for user ThePieCrusader
#
# Beginning Loop for user Ryu Min seok
# 	-Got the puuid for user Ryu Min seok.
# 	-Completed getting all current patch Match IDs for user Ryu Min seok
# 	-There are 315 users left.
# 	-Completed 6 Match IDs for user Ryu Min seok
#
# Beginning Loop for user mohawk
# 	-Got the puuid for user mohawk.
# 	-Created timeline_data_user_mohawk_end_250.json
# 	-Created other_game_data_user_mohawk_end_250.json
#
# 	-Completed getting all current patch Match IDs for user mohawk
# 	-There are 314 users left.
# 	-Completed 15 Match IDs for user mohawk
#
# Beginning Loop for user Asherannea
# 	-Got the puuid for user Asherannea.
# 	-Completed getting all current patch Match IDs for user Asherannea
# 	-There are 313 users left.
# 	-Completed 0 Match IDs for user Asherannea
#
# Beginning Loop for user excz
# 	-Got the puuid for user excz.
# 	-Completed getting all current patch Match IDs for user excz
# 	-There are 312 users left.
# 	-Completed 1 Match IDs for user excz
#
# Beginning Loop for user Kenvi
# 	-Got the puuid for user Kenvi.
# 	-Completed getting all current patch Match IDs for user Kenvi
# 	-There are 311 users left.
# 	-Completed 2 Match IDs for user Kenvi
#
# Beginning Loop for user Muffined
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Got the puuid for user Muffined.
# 	-Completed getting all current patch Match IDs for user Muffined
# 	-There are 310 users left.
# 	-Completed 1 Match IDs for user Muffined
#
# Beginning Loop for user mid ruin
# 	-Got the puuid for user mid ruin.
# 	-Completed getting all current patch Match IDs for user mid ruin
# 	-There are 309 users left.
# 	-Completed 0 Match IDs for user mid ruin
#
# Beginning Loop for user Korean Gukbbong
# 	-Got the puuid for user Korean Gukbbong.
# 	-Completed getting all current patch Match IDs for user Korean Gukbbong
# 	-There are 308 users left.
# 	-Completed 0 Match IDs for user Korean Gukbbong
#
# Beginning Loop for user Kindergarten
# 	-Got the puuid for user Kindergarten.
# 	-Completed getting all current patch Match IDs for user Kindergarten
# 	-There are 307 users left.
# 	-Completed 7 Match IDs for user Kindergarten
#
# Beginning Loop for user IcathianVoidd
# 	-Got the puuid for user IcathianVoidd.
# 	-Completed getting all current patch Match IDs for user IcathianVoidd
# 	-There are 306 users left.
# 	-Completed 1 Match IDs for user IcathianVoidd
#
# Beginning Loop for user XYG  Xu Jian
# 	-Got the puuid for user XYG  Xu Jian.
# 	-Completed getting all current patch Match IDs for user XYG  Xu Jian
# 	-There are 305 users left.
# 	-Completed 2 Match IDs for user XYG  Xu Jian
#
# Beginning Loop for user MeNoHaxor
# 	-Got the puuid for user MeNoHaxor.
# 	-Completed getting all current patch Match IDs for user MeNoHaxor
# 	-There are 304 users left.
# 	-Completed 2 Match IDs for user MeNoHaxor
#
# Beginning Loop for user Stach
# 	-Got the puuid for user Stach.
# 	-Completed getting all current patch Match IDs for user Stach
# 	-There are 303 users left.
# 	-Completed 6 Match IDs for user Stach
#
# Beginning Loop for user Squidsauce
# 	-Got the puuid for user Squidsauce.
# 	-Completed getting all current patch Match IDs for user Squidsauce
# 	-There are 302 users left.
# 	-Completed 4 Match IDs for user Squidsauce
#
# Beginning Loop for user Pupupu2
# 	-Got the puuid for user Pupupu2.
# 	-Completed getting all current patch Match IDs for user Pupupu2
# 	-There are 301 users left.
# 	-Completed 0 Match IDs for user Pupupu2
#
# Beginning Loop for user Bmfx
# 	-Got the puuid for user Bmfx.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user Bmfx
# 	-There are 300 users left.
# 	-Completed 8 Match IDs for user Bmfx
#
# Beginning Loop for user Truth Dragon
# 	-Got the puuid for user Truth Dragon.
# 	-Completed getting all current patch Match IDs for user Truth Dragon
# 	-There are 299 users left.
# 	-Completed 0 Match IDs for user Truth Dragon
#
# Beginning Loop for user celena
# 	-Got the puuid for user celena.
# 	-Completed getting all current patch Match IDs for user celena
# 	-There are 298 users left.
# 	-Completed 19 Match IDs for user celena
#
# Beginning Loop for user BHSc
# 	-Got the puuid for user BHSc.
# 	-Completed getting all current patch Match IDs for user BHSc
# 	-There are 297 users left.
# 	-Completed 0 Match IDs for user BHSc
#
# Beginning Loop for user ToastyAlex
# 	-Got the puuid for user ToastyAlex.
# 	-Completed getting all current patch Match IDs for user ToastyAlex
# 	-There are 296 users left.
# 	-Completed 3 Match IDs for user ToastyAlex
#
# Beginning Loop for user last dance5
# 	-Got the puuid for user last dance5.
# 	-Completed getting all current patch Match IDs for user last dance5
# 	-There are 295 users left.
# 	-Completed 0 Match IDs for user last dance5
#
# Beginning Loop for user rainjacket fish
# 	-Got the puuid for user rainjacket fish.
# 	-Completed getting all current patch Match IDs for user rainjacket fish
# 	-There are 294 users left.
# 	-Completed 0 Match IDs for user rainjacket fish
#
# Beginning Loop for user Kacha
# 	-Got the puuid for user Kacha.
# 	-Completed getting all current patch Match IDs for user Kacha
# 	-There are 293 users left.
# 	-Completed 0 Match IDs for user Kacha
#
# Beginning Loop for user MerryHel
# 	-Got the puuid for user MerryHel.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user MerryHel
# 	-There are 292 users left.
# 	-Completed 4 Match IDs for user MerryHel
#
# Beginning Loop for user TrexKz
# 	-Got the puuid for user TrexKz.
# 	-Completed getting all current patch Match IDs for user TrexKz
# 	-There are 291 users left.
# 	-Completed 8 Match IDs for user TrexKz
#
# Beginning Loop for user Dreamday
# 	-Got the puuid for user Dreamday.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user Dreamday
# 	-There are 290 users left.
# 	-Completed 25 Match IDs for user Dreamday
#
# Beginning Loop for user Hasie
# 	-Got the puuid for user Hasie.
# 	-Completed getting all current patch Match IDs for user Hasie
# 	-There are 289 users left.
# 	-Completed 4 Match IDs for user Hasie
#
# Beginning Loop for user hi im ming2
# 	-Got the puuid for user hi im ming2.
# 	-Completed getting all current patch Match IDs for user hi im ming2
# 	-There are 288 users left.
# 	-Completed 12 Match IDs for user hi im ming2
#
# Beginning Loop for user tenacityyy
# 	-Got the puuid for user tenacityyy.
# 	-Completed getting all current patch Match IDs for user tenacityyy
# 	-There are 287 users left.
# 	-Completed 6 Match IDs for user tenacityyy
#
# Beginning Loop for user GSDFQWASD
# 	-Got the puuid for user GSDFQWASD.
# 	-Completed getting all current patch Match IDs for user GSDFQWASD
# 	-There are 286 users left.
# 	-Completed 0 Match IDs for user GSDFQWASD
#
# Beginning Loop for user SC itssyaboinate
# 	-Got the puuid for user SC itssyaboinate.
# 	-Completed getting all current patch Match IDs for user SC itssyaboinate
# 	-There are 285 users left.
# 	-Completed 0 Match IDs for user SC itssyaboinate
#
# Beginning Loop for user Jido
# 	-Got the puuid for user Jido.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user Jido
# 	-There are 284 users left.
# 	-Completed 4 Match IDs for user Jido
#
# Beginning Loop for user QuinnAD
# 	-Got the puuid for user QuinnAD.
# 	-Completed getting all current patch Match IDs for user QuinnAD
# 	-There are 283 users left.
# 	-Completed 0 Match IDs for user QuinnAD
#
# Beginning Loop for user TrevorKTran
# 	-Got the puuid for user TrevorKTran.
# 	-Completed getting all current patch Match IDs for user TrevorKTran
# 	-There are 282 users left.
# 	-Completed 0 Match IDs for user TrevorKTran
#
# Beginning Loop for user Pobelter
# 	-Got the puuid for user Pobelter.
# 	-Completed getting all current patch Match IDs for user Pobelter
# 	-There are 281 users left.
# 	-Completed 0 Match IDs for user Pobelter
#
# Beginning Loop for user Swagnar
# 	-Got the puuid for user Swagnar.
# 	-Completed getting all current patch Match IDs for user Swagnar
# 	-There are 280 users left.
# 	-Completed 0 Match IDs for user Swagnar
#
# Beginning Loop for user US 101
# 	-Got the puuid for user US 101.
# 	-Completed getting all current patch Match IDs for user US 101
# 	-There are 279 users left.
# 	-Completed 9 Match IDs for user US 101
#
# Beginning Loop for user His Final Shot
# 	-Got the puuid for user His Final Shot.
# 	-Completed getting all current patch Match IDs for user His Final Shot
# 	-There are 278 users left.
# 	-Completed 0 Match IDs for user His Final Shot
#
# Beginning Loop for user Niikaido
# 	-Got the puuid for user Niikaido.
# 	-Completed getting all current patch Match IDs for user Niikaido
# 	-There are 277 users left.
# 	-Completed 4 Match IDs for user Niikaido
#
# Beginning Loop for user Riot Koyuncu
# 	-Got the puuid for user Riot Koyuncu.
# 	-Completed getting all current patch Match IDs for user Riot Koyuncu
# 	-There are 276 users left.
# 	-Completed 4 Match IDs for user Riot Koyuncu
#
# Beginning Loop for user sprinklrr
# 	-Got the puuid for user sprinklrr.
# 	-Completed getting all current patch Match IDs for user sprinklrr
# 	-There are 275 users left.
# 	-Completed 3 Match IDs for user sprinklrr
#
# Beginning Loop for user DoYouLikeHotPot
# 	-Got the puuid for user DoYouLikeHotPot.
# 	-Completed getting all current patch Match IDs for user DoYouLikeHotPot
# 	-There are 274 users left.
# 	-Completed 2 Match IDs for user DoYouLikeHotPot
#
# Beginning Loop for user XxUntitledxX
# 	-Got the puuid for user XxUntitledxX.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user XxUntitledxX
# 	-There are 273 users left.
# 	-Completed 5 Match IDs for user XxUntitledxX
#
# Beginning Loop for user UnDankDragon
# 	-Got the puuid for user UnDankDragon.
# 	-Completed getting all current patch Match IDs for user UnDankDragon
# 	-There are 272 users left.
# 	-Completed 1 Match IDs for user UnDankDragon
#
# Beginning Loop for user Pyoneer
# 	-Got the puuid for user Pyoneer.
# 	-Completed getting all current patch Match IDs for user Pyoneer
# 	-There are 271 users left.
# 	-Completed 7 Match IDs for user Pyoneer
#
# Beginning Loop for user qunianhuakai
# 	-Got the puuid for user qunianhuakai.
# 	-Completed getting all current patch Match IDs for user qunianhuakai
# 	-There are 270 users left.
# 	-Completed 0 Match IDs for user qunianhuakai
#
# Beginning Loop for user Dougie
# 	-Got the puuid for user Dougie.
# 	-Completed getting all current patch Match IDs for user Dougie
# 	-There are 269 users left.
# 	-Completed 0 Match IDs for user Dougie
#
# Beginning Loop for user 2Maxim
# Completed 100 users of 368!
#
# 	-Got the puuid for user 2Maxim.
# 	-Completed getting all current patch Match IDs for user 2Maxim
# 	-There are 268 users left.
# 	-Completed 0 Match IDs for user 2Maxim
#
# Beginning Loop for user DemonicBug
# 	-Got the puuid for user DemonicBug.
# 	-Completed getting all current patch Match IDs for user DemonicBug
# 	-There are 267 users left.
# 	-Completed 3 Match IDs for user DemonicBug
#
# Beginning Loop for user neukda3
# 	-Got the puuid for user neukda3.
# 	-Completed getting all current patch Match IDs for user neukda3
# 	-There are 266 users left.
# 	-Completed 0 Match IDs for user neukda3
#
# Beginning Loop for user Lark
# 	-Got the puuid for user Lark.
# 	-Completed getting all current patch Match IDs for user Lark
# 	-There are 265 users left.
# 	-Completed 0 Match IDs for user Lark
#
# Beginning Loop for user CR Sheherher
# 	-Got the puuid for user CR Sheherher.
# 	-Completed getting all current patch Match IDs for user CR Sheherher
# 	-There are 264 users left.
# 	-Completed 0 Match IDs for user CR Sheherher
#
# Beginning Loop for user Dear Vista
# 	-Got the puuid for user Dear Vista.
# 	-Completed getting all current patch Match IDs for user Dear Vista
# 	-There are 263 users left.
# 	-Completed 5 Match IDs for user Dear Vista
#
# Beginning Loop for user Daption
# 	-Got the puuid for user Daption.
# 	-Completed getting all current patch Match IDs for user Daption
# 	-There are 262 users left.
# 	-Completed 0 Match IDs for user Daption
#
# Beginning Loop for user raheen1
# 	-Got the puuid for user raheen1.
# 	-Completed getting all current patch Match IDs for user raheen1
# 	-There are 261 users left.
# 	-Completed 4 Match IDs for user raheen1
#
# Beginning Loop for user Not Sengo
# 	-Got the puuid for user Not Sengo.
# 	-Completed getting all current patch Match IDs for user Not Sengo
# 	-There are 260 users left.
# 	-Completed 0 Match IDs for user Not Sengo
#
# Beginning Loop for user YourLastLaugh
# 	-Got the puuid for user YourLastLaugh.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user YourLastLaugh
# 	-There are 259 users left.
# 	-Completed 7 Match IDs for user YourLastLaugh
#
# Beginning Loop for user Yaoyue
# 	-Got the puuid for user Yaoyue.
# 	-Completed getting all current patch Match IDs for user Yaoyue
# 	-There are 258 users left.
# 	-Completed 4 Match IDs for user Yaoyue
#
# Beginning Loop for user Ketie Pie
# 	-Got the puuid for user Ketie Pie.
# 	-Completed getting all current patch Match IDs for user Ketie Pie
# 	-There are 257 users left.
# 	-Completed 3 Match IDs for user Ketie Pie
#
# Beginning Loop for user Noyoustink
# 	-Got the puuid for user Noyoustink.
# 	-Completed getting all current patch Match IDs for user Noyoustink
# 	-There are 256 users left.
# 	-Completed 0 Match IDs for user Noyoustink
#
# Beginning Loop for user Branagh
# 	-Got the puuid for user Branagh.
# 	-Completed getting all current patch Match IDs for user Branagh
# 	-There are 255 users left.
# 	-Completed 7 Match IDs for user Branagh
#
# Beginning Loop for user Felauri
# 	-Got the puuid for user Felauri.
# 	-Completed getting all current patch Match IDs for user Felauri
# 	-There are 254 users left.
# 	-Completed 7 Match IDs for user Felauri
#
# Beginning Loop for user MozIy
# 	-Got the puuid for user MozIy.
# 	-Completed getting all current patch Match IDs for user MozIy
# 	-There are 253 users left.
# 	-Completed 3 Match IDs for user MozIy
#
# Beginning Loop for user Snowy Steps
# 	-Got the puuid for user Snowy Steps.
# 	-Completed getting all current patch Match IDs for user Snowy Steps
# 	-There are 252 users left.
# 	-Completed 0 Match IDs for user Snowy Steps
#
# Beginning Loop for user SoftReps
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Got the puuid for user SoftReps.
# 	-Completed getting all current patch Match IDs for user SoftReps
# 	-There are 251 users left.
# 	-Completed 0 Match IDs for user SoftReps
#
# Beginning Loop for user ApeXsnipe
# 	-Got the puuid for user ApeXsnipe.
# 	-Completed getting all current patch Match IDs for user ApeXsnipe
# 	-There are 250 users left.
# 	-Completed 1 Match IDs for user ApeXsnipe
#
# Beginning Loop for user LolGunSlinger
# 	-Got the puuid for user LolGunSlinger.
# 	-Completed getting all current patch Match IDs for user LolGunSlinger
# 	-There are 249 users left.
# 	-Completed 0 Match IDs for user LolGunSlinger
#
# Beginning Loop for user 7ach
# 	-Got the puuid for user 7ach.
# 	-Completed getting all current patch Match IDs for user 7ach
# 	-There are 248 users left.
# 	-Completed 11 Match IDs for user 7ach
#
# Beginning Loop for user 2sky
# 	-Got the puuid for user 2sky.
# 	-Completed getting all current patch Match IDs for user 2sky
# 	-There are 247 users left.
# 	-Completed 8 Match IDs for user 2sky
#
# Beginning Loop for user iite cool
# 	-Got the puuid for user iite cool.
# 	-Completed getting all current patch Match IDs for user iite cool
# 	-There are 246 users left.
# 	-Completed 9 Match IDs for user iite cool
#
# Beginning Loop for user Qitong
# 	-Got the puuid for user Qitong.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Created timeline_data_user_Qitong_end_500.json
# 	-Created other_game_data_user_Qitong_end_500.json
#
# 	-Completed getting all current patch Match IDs for user Qitong
# 	-There are 245 users left.
# 	-Completed 19 Match IDs for user Qitong
#
# Beginning Loop for user Geriatric Canyon
# 	-Got the puuid for user Geriatric Canyon.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user Geriatric Canyon
# 	-There are 244 users left.
# 	-Completed 15 Match IDs for user Geriatric Canyon
#
# Beginning Loop for user IceOnFires
# 	-Got the puuid for user IceOnFires.
# 	-Completed getting all current patch Match IDs for user IceOnFires
# 	-There are 243 users left.
# 	-Completed 10 Match IDs for user IceOnFires
#
# Beginning Loop for user WrongHoleOniChan
# 	-Got the puuid for user WrongHoleOniChan.
# 	-Completed getting all current patch Match IDs for user WrongHoleOniChan
# 	-There are 242 users left.
# 	-Completed 0 Match IDs for user WrongHoleOniChan
#
# Beginning Loop for user Le Dawn
# 	-Got the puuid for user Le Dawn.
# 	-Completed getting all current patch Match IDs for user Le Dawn
# 	-There are 241 users left.
# 	-Completed 3 Match IDs for user Le Dawn
#
# Beginning Loop for user Dear Miss L
# 	-Got the puuid for user Dear Miss L.
# 	-Completed getting all current patch Match IDs for user Dear Miss L
# 	-There are 240 users left.
# 	-Completed 7 Match IDs for user Dear Miss L
#
# Beginning Loop for user Li Bai
# 	-Got the puuid for user Li Bai.
# 	-Completed getting all current patch Match IDs for user Li Bai
# 	-There are 239 users left.
# 	-Completed 7 Match IDs for user Li Bai
#
# Beginning Loop for user SlayerPlayer
# 	-Got the puuid for user SlayerPlayer.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user SlayerPlayer
# 	-There are 238 users left.
# 	-Completed 7 Match IDs for user SlayerPlayer
#
# Beginning Loop for user DaffyDuckk
# 	-Got the puuid for user DaffyDuckk.
# 	-Completed getting all current patch Match IDs for user DaffyDuckk
# 	-There are 237 users left.
# 	-Completed 0 Match IDs for user DaffyDuckk
#
# Beginning Loop for user Wxx REB20201
# Something went wrong! Status Code: 404. Did not get puuid for user: Wxx REB20201
# Skipping this user. There are 236 users left.
#
# Beginning Loop for user Tachibana Marika
# 	-Got the puuid for user Tachibana Marika.
# 	-Completed getting all current patch Match IDs for user Tachibana Marika
# 	-There are 235 users left.
# 	-Completed 8 Match IDs for user Tachibana Marika
#
# Beginning Loop for user Topo
# 	-Got the puuid for user Topo.
# 	-Completed getting all current patch Match IDs for user Topo
# 	-There are 234 users left.
# 	-Completed 3 Match IDs for user Topo
#
# Beginning Loop for user IS THAT FEEDABOI
# 	-Got the puuid for user IS THAT FEEDABOI.
# 	-Completed getting all current patch Match IDs for user IS THAT FEEDABOI
# 	-There are 233 users left.
# 	-Completed 0 Match IDs for user IS THAT FEEDABOI
#
# Beginning Loop for user Oronuke
# 	-Got the puuid for user Oronuke.
# 	-Completed getting all current patch Match IDs for user Oronuke
# 	-There are 232 users left.
# 	-Completed 3 Match IDs for user Oronuke
#
# Beginning Loop for user its your funeral
# 	-Got the puuid for user its your funeral.
# 	-Completed getting all current patch Match IDs for user its your funeral
# 	-There are 231 users left.
# 	-Completed 6 Match IDs for user its your funeral
#
# Beginning Loop for user Satoshi
# 	-Got the puuid for user Satoshi.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user Satoshi
# 	-There are 230 users left.
# 	-Completed 11 Match IDs for user Satoshi
#
# Beginning Loop for user happyheart
# 	-Got the puuid for user happyheart.
# 	-Completed getting all current patch Match IDs for user happyheart
# 	-There are 229 users left.
# 	-Completed 12 Match IDs for user happyheart
#
# Beginning Loop for user KingGeorgie
# 	-Got the puuid for user KingGeorgie.
# 	-Completed getting all current patch Match IDs for user KingGeorgie
# 	-There are 228 users left.
# 	-Completed 1 Match IDs for user KingGeorgie
#
# Beginning Loop for user Oldmanguy
# 	-Got the puuid for user Oldmanguy.
# 	-Completed getting all current patch Match IDs for user Oldmanguy
# 	-There are 227 users left.
# 	-Completed 0 Match IDs for user Oldmanguy
#
# Beginning Loop for user pos2
# 	-Got the puuid for user pos2.
# 	-Completed getting all current patch Match IDs for user pos2
# 	-There are 226 users left.
# 	-Completed 0 Match IDs for user pos2
#
# Beginning Loop for user end credits
# 	-Got the puuid for user end credits.
# 	-Completed getting all current patch Match IDs for user end credits
# 	-There are 225 users left.
# 	-Completed 1 Match IDs for user end credits
#
# Beginning Loop for user Shaunder
# 	-Got the puuid for user Shaunder.
# 	-Completed getting all current patch Match IDs for user Shaunder
# 	-There are 224 users left.
# 	-Completed 3 Match IDs for user Shaunder
#
# Beginning Loop for user Zethal
# 	-Got the puuid for user Zethal.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user Zethal
# 	-There are 223 users left.
# 	-Completed 10 Match IDs for user Zethal
#
# Beginning Loop for user Unity
# 	-Got the puuid for user Unity.
# 	-Completed getting all current patch Match IDs for user Unity
# 	-There are 222 users left.
# 	-Completed 12 Match IDs for user Unity
#
# Beginning Loop for user love morning
# 	-Got the puuid for user love morning .
# 	-Completed getting all current patch Match IDs for user love morning
# 	-There are 221 users left.
# 	-Completed 0 Match IDs for user love morning
#
# Beginning Loop for user Sosig
# 	-Got the puuid for user Sosig.
# 	-Completed getting all current patch Match IDs for user Sosig
# 	-There are 220 users left.
# 	-Completed 7 Match IDs for user Sosig
#
# Beginning Loop for user SweatyToast
# 	-Got the puuid for user SweatyToast.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user SweatyToast
# 	-There are 219 users left.
# 	-Completed 18 Match IDs for user SweatyToast
#
# Beginning Loop for user Gmandlife
# 	-Got the puuid for user Gmandlife.
# 	-Completed getting all current patch Match IDs for user Gmandlife
# 	-There are 218 users left.
# 	-Completed 2 Match IDs for user Gmandlife
#
# Beginning Loop for user Dark Energy
# 	-Got the puuid for user Dark Energy.
# 	-Completed getting all current patch Match IDs for user Dark Energy
# 	-There are 217 users left.
# 	-Completed 2 Match IDs for user Dark Energy
#
# Beginning Loop for user May it be
# 	-Got the puuid for user May it be.
# 	-Completed getting all current patch Match IDs for user May it be
# 	-There are 216 users left.
# 	-Completed 13 Match IDs for user May it be
#
# Beginning Loop for user IllIIIIlIIIlIIII
# 	-Got the puuid for user IllIIIIlIIIlIIII.
# 	-Completed getting all current patch Match IDs for user IllIIIIlIIIlIIII
# 	-There are 215 users left.
# 	-Completed 0 Match IDs for user IllIIIIlIIIlIIII
#
# Beginning Loop for user 184 166 217
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Got the puuid for user 184 166 217.
# 	-Completed getting all current patch Match IDs for user 184 166 217
# 	-There are 214 users left.
# 	-Completed 0 Match IDs for user 184 166 217
#
# Beginning Loop for user Dizley
# 	-Got the puuid for user Dizley.
# 	-Completed getting all current patch Match IDs for user Dizley
# 	-There are 213 users left.
# 	-Completed 1 Match IDs for user Dizley
#
# Beginning Loop for user Ledah
# 	-Got the puuid for user Ledah.
# 	-Completed getting all current patch Match IDs for user Ledah
# 	-There are 212 users left.
# 	-Completed 0 Match IDs for user Ledah
#
# Beginning Loop for user eL eL TRIGGER
# 	-Got the puuid for user eL eL TRIGGER.
# 	-Completed getting all current patch Match IDs for user eL eL TRIGGER
# 	-There are 211 users left.
# 	-Completed 0 Match IDs for user eL eL TRIGGER
#
# Beginning Loop for user MasterMonkeyNA
# 	-Got the puuid for user MasterMonkeyNA.
# 	-Completed getting all current patch Match IDs for user MasterMonkeyNA
# 	-There are 210 users left.
# 	-Completed 0 Match IDs for user MasterMonkeyNA
#
# Beginning Loop for user NA IS A ZOO
# 	-Got the puuid for user NA IS A ZOO.
# 	-Completed getting all current patch Match IDs for user NA IS A ZOO
# 	-There are 209 users left.
# 	-Completed 5 Match IDs for user NA IS A ZOO
#
# Beginning Loop for user animegirl2007
# 	-Got the puuid for user animegirl2007.
# 	-Completed getting all current patch Match IDs for user animegirl2007
# 	-There are 208 users left.
# 	-Completed 11 Match IDs for user animegirl2007
#
# Beginning Loop for user Hub5
# 	-Got the puuid for user Hub5.
# 	-Completed getting all current patch Match IDs for user Hub5
# 	-There are 207 users left.
# 	-Completed 6 Match IDs for user Hub5
#
# Beginning Loop for user Rositajonez
# 	-Got the puuid for user Rositajonez.
# 	-Completed getting all current patch Match IDs for user Rositajonez
# 	-There are 206 users left.
# 	-Completed 0 Match IDs for user Rositajonez
#
# Beginning Loop for user Fallouch
# 	-Got the puuid for user Fallouch.
# 	-Completed getting all current patch Match IDs for user Fallouch
# 	-There are 205 users left.
# 	-Completed 1 Match IDs for user Fallouch
#
# Beginning Loop for user Just Trust Gala8
# 	-Got the puuid for user Just Trust Gala8.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user Just Trust Gala8
# 	-There are 204 users left.
# 	-Completed 7 Match IDs for user Just Trust Gala8
#
# Beginning Loop for user sexer
# 	-Got the puuid for user sexer.
# 	-Completed getting all current patch Match IDs for user sexer
# 	-There are 203 users left.
# 	-Completed 4 Match IDs for user sexer
#
# Beginning Loop for user Piriya
# 	-Got the puuid for user Piriya.
# 	-Completed getting all current patch Match IDs for user Piriya
# 	-There are 202 users left.
# 	-Completed 2 Match IDs for user Piriya
#
# Beginning Loop for user Moon97
# 	-Got the puuid for user Moon97.
# 	-Completed getting all current patch Match IDs for user Moon97
# 	-There are 201 users left.
# 	-Completed 9 Match IDs for user Moon97
#
# Beginning Loop for user Akeha
# 	-Got the puuid for user Akeha.
# 	-Completed getting all current patch Match IDs for user Akeha
# 	-There are 200 users left.
# 	-Completed 0 Match IDs for user Akeha
#
# Beginning Loop for user Rayburn
# 	-Got the puuid for user Rayburn.
# 	-Completed getting all current patch Match IDs for user Rayburn
# 	-There are 199 users left.
# 	-Completed 3 Match IDs for user Rayburn
#
# Beginning Loop for user Rocky9
# 	-Got the puuid for user Rocky9.
# 	-Completed getting all current patch Match IDs for user Rocky9
# 	-There are 198 users left.
# 	-Completed 0 Match IDs for user Rocky9
#
# Beginning Loop for user Antoine1234567
# 	-Got the puuid for user Antoine1234567.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user Antoine1234567
# 	-There are 197 users left.
# 	-Completed 16 Match IDs for user Antoine1234567
#
# Beginning Loop for user Daisoujou
# 	-Got the puuid for user Daisoujou.
# 	-Completed getting all current patch Match IDs for user Daisoujou
# 	-There are 196 users left.
# 	-Completed 0 Match IDs for user Daisoujou
#
# Beginning Loop for user Outplay
# 	-Got the puuid for user Outplay.
# 	-Completed getting all current patch Match IDs for user Outplay
# 	-There are 195 users left.
# 	-Completed 3 Match IDs for user Outplay
#
# Beginning Loop for user Just so so
# 	-Got the puuid for user Just so so.
# 	-Completed getting all current patch Match IDs for user Just so so
# 	-There are 194 users left.
# 	-Completed 9 Match IDs for user Just so so
#
# Beginning Loop for user Threesicksty
# 	-Got the puuid for user Threesicksty.
# 	-Completed getting all current patch Match IDs for user Threesicksty
# 	-There are 193 users left.
# 	-Completed 0 Match IDs for user Threesicksty
#
# Beginning Loop for user 4rch
# 	-Got the puuid for user 4rch.
# 	-Completed getting all current patch Match IDs for user 4rch
# 	-There are 192 users left.
# 	-Completed 1 Match IDs for user 4rch
#
# Beginning Loop for user buhudong
# Something went wrong! Status Code: 404. Did not get puuid for user: buhudong
# Skipping this user. There are 191 users left.
#
# Beginning Loop for user NaCl Tim
# 	-Got the puuid for user NaCl Tim.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Created timeline_data_user_NaCl Tim_end_750.json
# 	-Created other_game_data_user_NaCl Tim_end_750.json
#
# 	-Completed getting all current patch Match IDs for user NaCl Tim
# 	-There are 190 users left.
# 	-Completed 33 Match IDs for user NaCl Tim
#
# Beginning Loop for user chias
# Something went wrong! Status Code: 404. Did not get puuid for user: chias
# Skipping this user. There are 189 users left.
#
# Beginning Loop for user slogan1
# 	-Got the puuid for user slogan1.
# 	-Completed getting all current patch Match IDs for user slogan1
# 	-There are 188 users left.
# 	-Completed 1 Match IDs for user slogan1
#
# Beginning Loop for user kevintianXD
# 	-Got the puuid for user kevintianXD.
# 	-Completed getting all current patch Match IDs for user kevintianXD
# 	-There are 187 users left.
# 	-Completed 0 Match IDs for user kevintianXD
#
# Beginning Loop for user Messages
# 	-Got the puuid for user Messages.
# 	-Completed getting all current patch Match IDs for user Messages
# 	-There are 186 users left.
# 	-Completed 0 Match IDs for user Messages
#
# Beginning Loop for user Piki
# 	-Got the puuid for user Piki.
# 	-Completed getting all current patch Match IDs for user Piki
# 	-There are 185 users left.
# 	-Completed 1 Match IDs for user Piki
#
# Beginning Loop for user Jared Klein
# 	-Got the puuid for user Jared Klein.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user Jared Klein
# 	-There are 184 users left.
# 	-Completed 3 Match IDs for user Jared Klein
#
# Beginning Loop for user Logia
# 	-Got the puuid for user Logia.
# 	-Completed getting all current patch Match IDs for user Logia
# 	-There are 183 users left.
# 	-Completed 5 Match IDs for user Logia
#
# Beginning Loop for user Backuping
# 	-Got the puuid for user Backuping.
# 	-Completed getting all current patch Match IDs for user Backuping
# 	-There are 182 users left.
# 	-Completed 0 Match IDs for user Backuping
#
# Beginning Loop for user tomeito
# 	-Got the puuid for user tomeito.
# 	-Completed getting all current patch Match IDs for user tomeito
# 	-There are 181 users left.
# 	-Completed 0 Match IDs for user tomeito
#
# Beginning Loop for user Kyuki
# 	-Got the puuid for user Kyuki.
# 	-Completed getting all current patch Match IDs for user Kyuki
# 	-There are 180 users left.
# 	-Completed 11 Match IDs for user Kyuki
#
# Beginning Loop for user a redemption arc
# 	-Got the puuid for user a redemption arc.
# 	-Completed getting all current patch Match IDs for user a redemption arc
# 	-There are 179 users left.
# 	-Completed 0 Match IDs for user a redemption arc
#
# Beginning Loop for user Thats Not Fervor
# 	-Got the puuid for user Thats Not Fervor.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user Thats Not Fervor
# 	-There are 178 users left.
# 	-Completed 15 Match IDs for user Thats Not Fervor
#
# Beginning Loop for user GankedBy Bush
# 	-Got the puuid for user GankedBy Bush.
# 	-Completed getting all current patch Match IDs for user GankedBy Bush
# 	-There are 177 users left.
# 	-Completed 12 Match IDs for user GankedBy Bush
#
# Beginning Loop for user Scarlet Symphony
# 	-Got the puuid for user Scarlet Symphony.
# 	-Completed getting all current patch Match IDs for user Scarlet Symphony
# 	-There are 176 users left.
# 	-Completed 5 Match IDs for user Scarlet Symphony
#
# Beginning Loop for user BE Bodast
# 	-Got the puuid for user BE Bodast.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user BE Bodast
# 	-There are 175 users left.
# 	-Completed 14 Match IDs for user BE Bodast
#
# Beginning Loop for user Dvein In
# 	-Got the puuid for user Dvein In.
# 	-Completed getting all current patch Match IDs for user Dvein In
# 	-There are 174 users left.
# 	-Completed 0 Match IDs for user Dvein In
#
# Beginning Loop for user stinkyfinger721
# 	-Got the puuid for user stinkyfinger721.
# 	-Completed getting all current patch Match IDs for user stinkyfinger721
# 	-There are 173 users left.
# 	-Completed 8 Match IDs for user stinkyfinger721
#
# Beginning Loop for user SavorWolf
# 	-Got the puuid for user SavorWolf.
# 	-Completed getting all current patch Match IDs for user SavorWolf
# 	-There are 172 users left.
# 	-Completed 0 Match IDs for user SavorWolf
#
# Beginning Loop for user USC Inferno
# 	-Got the puuid for user USC Inferno .
# 	-Completed getting all current patch Match IDs for user USC Inferno
# 	-There are 171 users left.
# 	-Completed 7 Match IDs for user USC Inferno
#
# Beginning Loop for user Wanted Trixx
# 	-Got the puuid for user Wanted Trixx.
# 	-Completed getting all current patch Match IDs for user Wanted Trixx
# 	-There are 170 users left.
# 	-Completed 0 Match IDs for user Wanted Trixx
#
# Beginning Loop for user JJBA
# 	-Got the puuid for user JJBA.
# 	-Completed getting all current patch Match IDs for user JJBA
# 	-There are 169 users left.
# 	-Completed 6 Match IDs for user JJBA
#
# Beginning Loop for user cvxhi
# Completed 200 users of 368!
#
# 	-Got the puuid for user cvxhi.
# 	-Completed getting all current patch Match IDs for user cvxhi
# 	-There are 168 users left.
# 	-Completed 2 Match IDs for user cvxhi
#
# Beginning Loop for user ElitexLatino
# 	-Got the puuid for user ElitexLatino.
# 	-Completed getting all current patch Match IDs for user ElitexLatino
# 	-There are 167 users left.
# 	-Completed 1 Match IDs for user ElitexLatino
#
# Beginning Loop for user Danman96
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Got the puuid for user Danman96.
# 	-Completed getting all current patch Match IDs for user Danman96
# 	-There are 166 users left.
# 	-Completed 7 Match IDs for user Danman96
#
# Beginning Loop for user RexRequired
# 	-Got the puuid for user RexRequired.
# 	-Completed getting all current patch Match IDs for user RexRequired
# 	-There are 165 users left.
# 	-Completed 25 Match IDs for user RexRequired
#
# Beginning Loop for user NatsuDragneel14
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Got the puuid for user NatsuDragneel14.
# 	-Completed getting all current patch Match IDs for user NatsuDragneel14
# 	-There are 164 users left.
# 	-Completed 6 Match IDs for user NatsuDragneel14
#
# Beginning Loop for user Arc en ciel
# 	-Got the puuid for user Arc en ciel.
# 	-Completed getting all current patch Match IDs for user Arc en ciel
# 	-There are 163 users left.
# 	-Completed 11 Match IDs for user Arc en ciel
#
# Beginning Loop for user Monarch1
# 	-Got the puuid for user Monarch1.
# 	-Completed getting all current patch Match IDs for user Monarch1
# 	-There are 162 users left.
# 	-Completed 1 Match IDs for user Monarch1
#
# Beginning Loop for user I onIy Top
# 	-Got the puuid for user I onIy Top.
# 	-Completed getting all current patch Match IDs for user I onIy Top
# 	-There are 161 users left.
# 	-Completed 0 Match IDs for user I onIy Top
#
# Beginning Loop for user Harambe
# 	-Got the puuid for user Harambe.
# 	-Completed getting all current patch Match IDs for user Harambe
# 	-There are 160 users left.
# 	-Completed 2 Match IDs for user Harambe
#
# Beginning Loop for user Diomarr
# 	-Got the puuid for user Diomarr.
# 	-Completed getting all current patch Match IDs for user Diomarr
# 	-There are 159 users left.
# 	-Completed 0 Match IDs for user Diomarr
#
# Beginning Loop for user Nightstar
# 	-Got the puuid for user Nightstar.
# 	-No match ID for user Nightstar. Skipping this user!
# 	-Completed 1 Match IDs for user Nightstar
#
# Beginning Loop for user chomaker
# 	-Got the puuid for user chomaker.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user chomaker
# 	-There are 157 users left.
# 	-Completed 13 Match IDs for user chomaker
#
# Beginning Loop for user jie jie yong li
# 	-Got the puuid for user jie jie yong li.
# 	-Completed getting all current patch Match IDs for user jie jie yong li
# 	-There are 156 users left.
# 	-Completed 12 Match IDs for user jie jie yong li
#
# Beginning Loop for user belowzero
# 	-Got the puuid for user belowzero.
# 	-Completed getting all current patch Match IDs for user belowzero
# 	-There are 155 users left.
# 	-Completed 6 Match IDs for user belowzero
#
# Beginning Loop for user I Main Top Lane
# 	-Got the puuid for user I Main Top Lane.
# 	-Completed getting all current patch Match IDs for user I Main Top Lane
# 	-There are 154 users left.
# 	-Completed 3 Match IDs for user I Main Top Lane
#
# Beginning Loop for user bknormbk
# 	-Got the puuid for user bknormbk.
# 	-Completed getting all current patch Match IDs for user bknormbk
# 	-There are 153 users left.
# 	-Completed 1 Match IDs for user bknormbk
#
# Beginning Loop for user Gpdz
# 	-Got the puuid for user Gpdz.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user Gpdz
# 	-There are 152 users left.
# 	-Completed 4 Match IDs for user Gpdz
#
# Beginning Loop for user Citric
# 	-Got the puuid for user Citric.
# 	-Completed getting all current patch Match IDs for user Citric
# 	-There are 151 users left.
# 	-Completed 1 Match IDs for user Citric
#
# Beginning Loop for user Dotix
# 	-Got the puuid for user Dotix.
# 	-Completed getting all current patch Match IDs for user Dotix
# 	-There are 150 users left.
# 	-Completed 2 Match IDs for user Dotix
#
# Beginning Loop for user Xing ge ru ci
# ...
# 	-There are 74 users left.
# 	-Completed 13 Match IDs for user King Koney
#
# Beginning Loop for user Frog Maw
# 	-Got the puuid for user Frog Maw.
# 	-Completed getting all current patch Match IDs for user Frog Maw
# 	-There are 73 users left.
# 	-Completed 0 Match IDs for user Frog Maw
#
# Beginning Loop for user sucko
# 	-Got the puuid for user sucko.
# 	-Completed getting all current patch Match IDs for user sucko
# 	-There are 72 users left.
# 	-Completed 1 Match IDs for user sucko
#
# Beginning Loop for user Best Turtle IND
# 	-Got the puuid for user Best Turtle IND.
# 	-Completed getting all current patch Match IDs for user Best Turtle IND
# 	-There are 71 users left.
# 	-Completed 0 Match IDs for user Best Turtle IND
#
# Beginning Loop for user Eshyn
# 	-Got the puuid for user Eshyn.
# 	-Completed getting all current patch Match IDs for user Eshyn
# 	-There are 70 users left.
# 	-Completed 3 Match IDs for user Eshyn
#
# Beginning Loop for user BoilThe0il
# 	-Got the puuid for user BoilThe0il.
# 	-Completed getting all current patch Match IDs for user BoilThe0il
# 	-There are 69 users left.
# 	-Completed 5 Match IDs for user BoilThe0il
#
# Beginning Loop for user KORASIII
# Completed 300 users of 368!
#
# 	-Got the puuid for user KORASIII.
# 	-Completed getting all current patch Match IDs for user KORASIII
# 	-There are 68 users left.
# 	-Completed 3 Match IDs for user KORASIII
#
# Beginning Loop for user Kealan
# 	-Got the puuid for user Kealan.
# 	-Completed getting all current patch Match IDs for user Kealan
# 	-There are 67 users left.
# 	-Completed 0 Match IDs for user Kealan
#
# Beginning Loop for user Avinxx
# 	-Got the puuid for user Avinxx.
# 	-Completed getting all current patch Match IDs for user Avinxx
# 	-There are 66 users left.
# 	-Completed 0 Match IDs for user Avinxx
#
# Beginning Loop for user is this hell
# 	-Got the puuid for user is this hell.
# 	-Completed getting all current patch Match IDs for user is this hell
# 	-There are 65 users left.
# 	-Completed 7 Match IDs for user is this hell
#
# Beginning Loop for user Exothy
# 	-Got the puuid for user Exothy.
# 	-Completed getting all current patch Match IDs for user Exothy
# 	-There are 64 users left.
# 	-Completed 0 Match IDs for user Exothy
#
# Beginning Loop for user YourGFIsMySide
# Something went wrong! Status Code: 404. Did not get puuid for user: YourGFIsMySide
# Skipping this user. There are 63 users left.
#
# Beginning Loop for user Ribitey
# 	-Got the puuid for user Ribitey.
# 	-Completed getting all current patch Match IDs for user Ribitey
# 	-There are 62 users left.
# 	-Completed 2 Match IDs for user Ribitey
#
# Beginning Loop for user saku fan
# 	-Got the puuid for user saku fan.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user saku fan
# 	-There are 61 users left.
# 	-Completed 11 Match IDs for user saku fan
#
# Beginning Loop for user Blower
# 	-Got the puuid for user Blower.
# 	-Completed getting all current patch Match IDs for user Blower
# 	-There are 60 users left.
# 	-Completed 10 Match IDs for user Blower
#
# Beginning Loop for user SQKSQ Bottom
# 	-Got the puuid for user SQKSQ Bottom.
# 	-Completed getting all current patch Match IDs for user SQKSQ Bottom
# 	-There are 59 users left.
# 	-Completed 0 Match IDs for user SQKSQ Bottom
#
# Beginning Loop for user Facts
# 	-Got the puuid for user Facts.
# 	-Completed getting all current patch Match IDs for user Facts
# 	-There are 58 users left.
# 	-Completed 6 Match IDs for user Facts
#
# Beginning Loop for user 5tunt
# 	-Got the puuid for user 5tunt.
# 	-Completed getting all current patch Match IDs for user 5tunt
# 	-There are 57 users left.
# 	-Completed 0 Match IDs for user 5tunt
#
# Beginning Loop for user StrangerToLife
# 	-Got the puuid for user StrangerToLife.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user StrangerToLife
# 	-There are 56 users left.
# 	-Completed 5 Match IDs for user StrangerToLife
#
# Beginning Loop for user KryRa2
# 	-Got the puuid for user KryRa2.
# 	-Completed getting all current patch Match IDs for user KryRa2
# 	-There are 55 users left.
# 	-Completed 0 Match IDs for user KryRa2
#
# Beginning Loop for user joey mills
# 	-Got the puuid for user joey mills.
# 	-Completed getting all current patch Match IDs for user joey mills
# 	-There are 54 users left.
# 	-Completed 7 Match IDs for user joey mills
#
# Beginning Loop for user L Escape
# 	-Got the puuid for user L Escape.
# 	-Completed getting all current patch Match IDs for user L Escape
# 	-There are 53 users left.
# 	-Completed 0 Match IDs for user L Escape
#
# Beginning Loop for user Muwa
# 	-Got the puuid for user Muwa.
# 	-Completed getting all current patch Match IDs for user Muwa
# 	-There are 52 users left.
# 	-Completed 4 Match IDs for user Muwa
#
# Beginning Loop for user Lafran
# 	-Got the puuid for user Lafran.
# 	-Completed getting all current patch Match IDs for user Lafran
# 	-There are 51 users left.
# 	-Completed 2 Match IDs for user Lafran
#
# Beginning Loop for user Snow2
# 	-Got the puuid for user Snow2.
# 	-Completed getting all current patch Match IDs for user Snow2
# 	-There are 50 users left.
# 	-Completed 0 Match IDs for user Snow2
#
# Beginning Loop for user KryRa
# 	-Got the puuid for user KryRa.
# 	-Completed getting all current patch Match IDs for user KryRa
# 	-There are 49 users left.
# 	-Completed 5 Match IDs for user KryRa
#
# Beginning Loop for user           srtty9
# Something went wrong! Status Code: 404. Did not get puuid for user:           srtty9
# Skipping this user. There are 48 users left.
#
# Beginning Loop for user Businessman47
# 	-Got the puuid for user Businessman47.
# 	-Completed getting all current patch Match IDs for user Businessman47
# 	-There are 47 users left.
# 	-Completed 0 Match IDs for user Businessman47
#
# Beginning Loop for user Solaria
# 	-Got the puuid for user Solaria.
# 	-Completed getting all current patch Match IDs for user Solaria
# 	-There are 46 users left.
# 	-Completed 0 Match IDs for user Solaria
#
# Beginning Loop for user Bashful Iceberg
# 	-Got the puuid for user Bashful Iceberg.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user Bashful Iceberg
# 	-There are 45 users left.
# 	-Completed 8 Match IDs for user Bashful Iceberg
#
# Beginning Loop for user Blackcar223
# 	-Got the puuid for user Blackcar223.
# 	-Completed getting all current patch Match IDs for user Blackcar223
# 	-There are 44 users left.
# 	-Completed 1 Match IDs for user Blackcar223
#
# Beginning Loop for user coppersan
# 	-Got the puuid for user coppersan.
# 	-Completed getting all current patch Match IDs for user coppersan
# 	-There are 43 users left.
# 	-Completed 0 Match IDs for user coppersan
#
# Beginning Loop for user Mfe1
# 	-Got the puuid for user Mfe1.
# 	-Completed getting all current patch Match IDs for user Mfe1
# 	-There are 42 users left.
# 	-Completed 7 Match IDs for user Mfe1
#
# Beginning Loop for user Bejjj
# 	-Got the puuid for user Bejjj.
# 	-Completed getting all current patch Match IDs for user Bejjj
# 	-There are 41 users left.
# 	-Completed 1 Match IDs for user Bejjj
#
# Beginning Loop for user Irk Luigi
# 	-Got the puuid for user Irk Luigi.
# 	-Completed getting all current patch Match IDs for user Irk Luigi
# 	-There are 40 users left.
# 	-Completed 0 Match IDs for user Irk Luigi
#
# Beginning Loop for user Schwi
# 	-Got the puuid for user Schwi.
# 	-Completed getting all current patch Match IDs for user Schwi
# 	-There are 39 users left.
# 	-Completed 0 Match IDs for user Schwi
#
# Beginning Loop for user Sheiden2
# 	-Got the puuid for user Sheiden2.
# 	-Completed getting all current patch Match IDs for user Sheiden2
# 	-There are 38 users left.
# 	-Completed 4 Match IDs for user Sheiden2
#
# Beginning Loop for user GO0B
# 	-Got the puuid for user GO0B.
# 	-Completed getting all current patch Match IDs for user GO0B
# 	-There are 37 users left.
# 	-Completed 0 Match IDs for user GO0B
#
# Beginning Loop for user pissss
# 	-Got the puuid for user pissss.
# 	-Completed getting all current patch Match IDs for user pissss
# 	-There are 36 users left.
# 	-Completed 3 Match IDs for user pissss
#
# Beginning Loop for user ERICSMOM12KAYEAR
# 	-Got the puuid for user ERICSMOM12KAYEAR.
# 	-Completed getting all current patch Match IDs for user ERICSMOM12KAYEAR
# 	-There are 35 users left.
# 	-Completed 0 Match IDs for user ERICSMOM12KAYEAR
#
# Beginning Loop for user DevilUnikorn
# 	-Got the puuid for user DevilUnikorn.
# 	-Completed getting all current patch Match IDs for user DevilUnikorn
# 	-There are 34 users left.
# 	-Completed 7 Match IDs for user DevilUnikorn
#
# Beginning Loop for user A1C Masterby
# 	-Got the puuid for user A1C Masterby.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user A1C Masterby
# 	-There are 33 users left.
# 	-Completed 6 Match IDs for user A1C Masterby
#
# Beginning Loop for user PowerSmite
# 	-Got the puuid for user PowerSmite.
# 	-Completed getting all current patch Match IDs for user PowerSmite
# 	-There are 32 users left.
# 	-Completed 8 Match IDs for user PowerSmite
#
# Beginning Loop for user KroAaToa
# 	-Got the puuid for user KroAaToa.
# 	-Completed getting all current patch Match IDs for user KroAaToa
# 	-There are 31 users left.
# 	-Completed 3 Match IDs for user KroAaToa
#
# Beginning Loop for user Crimson Shuriken
# 	-Got the puuid for user Crimson Shuriken.
# 	-Completed getting all current patch Match IDs for user Crimson Shuriken
# 	-There are 30 users left.
# 	-Completed 5 Match IDs for user Crimson Shuriken
#
# Beginning Loop for user Haru De Wanai
# 	-Got the puuid for user Haru De Wanai.
# 	-Completed getting all current patch Match IDs for user Haru De Wanai
# 	-There are 29 users left.
# 	-Completed 6 Match IDs for user Haru De Wanai
#
# Beginning Loop for user moosehater
# 	-Got the puuid for user moosehater.
# 	-Completed getting all current patch Match IDs for user moosehater
# 	-There are 28 users left.
# 	-Completed 1 Match IDs for user moosehater
#
# Beginning Loop for user Murillo Sama
# 	-Got the puuid for user Murillo Sama.
# 	-Completed getting all current patch Match IDs for user Murillo Sama
# 	-There are 27 users left.
# 	-Completed 0 Match IDs for user Murillo Sama
#
# Beginning Loop for user Gandhi G
# 	-Got the puuid for user Gandhi G.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user Gandhi G
# 	-There are 26 users left.
# 	-Completed 5 Match IDs for user Gandhi G
#
# Beginning Loop for user BOBtimers Kitten
# 	-Got the puuid for user BOBtimers Kitten.
# 	-Completed getting all current patch Match IDs for user BOBtimers Kitten
# 	-There are 25 users left.
# 	-Completed 8 Match IDs for user BOBtimers Kitten
#
# Beginning Loop for user CC Shogo
# 	-Got the puuid for user CC Shogo.
# 	-Completed getting all current patch Match IDs for user CC Shogo
# 	-There are 24 users left.
# 	-Completed 9 Match IDs for user CC Shogo
#
# Beginning Loop for user Mood9
# 	-Got the puuid for user Mood9.
# 	-Completed getting all current patch Match IDs for user Mood9
# 	-There are 23 users left.
# 	-Completed 0 Match IDs for user Mood9
#
# Beginning Loop for user goge
# 	-Got the puuid for user goge.
# 	-Completed getting all current patch Match IDs for user goge
# 	-There are 22 users left.
# 	-Completed 0 Match IDs for user goge
#
# Beginning Loop for user Le chuL
# 	-Got the puuid for user Le chuL.
# 	-Completed getting all current patch Match IDs for user Le chuL
# 	-There are 21 users left.
# 	-Completed 1 Match IDs for user Le chuL
#
# Beginning Loop for user BabyQ
# 	-Got the puuid for user BabyQ.
# 	-Completed getting all current patch Match IDs for user BabyQ
# 	-There are 20 users left.
# 	-Completed 0 Match IDs for user BabyQ
#
# Beginning Loop for user I Reincarnated
# 	-Got the puuid for user I Reincarnated.
# 	-Completed getting all current patch Match IDs for user I Reincarnated
# 	-There are 19 users left.
# 	-Completed 0 Match IDs for user I Reincarnated
#
# Beginning Loop for user parrks
# 	-Got the puuid for user parrks.
# 	-Completed getting all current patch Match IDs for user parrks
# 	-There are 18 users left.
# 	-Completed 3 Match IDs for user parrks
#
# Beginning Loop for user Tomgoku
# 	-Got the puuid for user Tomgoku.
# 	-Completed getting all current patch Match IDs for user Tomgoku
# 	-There are 17 users left.
# 	-Completed 0 Match IDs for user Tomgoku
#
# Beginning Loop for user Scafe
# 	-Got the puuid for user Scafe.
# 	-Completed getting all current patch Match IDs for user Scafe
# 	-There are 16 users left.
# 	-Completed 0 Match IDs for user Scafe
#
# Beginning Loop for user HULKSMASH1337
# 	-Got the puuid for user HULKSMASH1337.
# 	-Created timeline_data_user_HULKSMASH1337_end_1500.json
# 	-Created other_game_data_user_HULKSMASH1337_end_1500.json
#
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user HULKSMASH1337
# 	-There are 15 users left.
# 	-Completed 19 Match IDs for user HULKSMASH1337
#
# Beginning Loop for user omero combo 4
# 	-Got the puuid for user omero combo 4.
# 	-Completed getting all current patch Match IDs for user omero combo 4
# 	-There are 14 users left.
# 	-Completed 4 Match IDs for user omero combo 4
#
# Beginning Loop for user Ainyy
# 	-Got the puuid for user Ainyy.
# 	-Completed getting all current patch Match IDs for user Ainyy
# 	-There are 13 users left.
# 	-Completed 2 Match IDs for user Ainyy
#
# Beginning Loop for user DarkX
# 	-Got the puuid for user DarkX.
# 	-Completed getting all current patch Match IDs for user DarkX
# 	-There are 12 users left.
# 	-Completed 5 Match IDs for user DarkX
#
# Beginning Loop for user Acereal
# 	-Got the puuid for user Acereal.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user Acereal
# 	-There are 11 users left.
# 	-Completed 17 Match IDs for user Acereal
#
# Beginning Loop for user KatEvolved
# 	-Got the puuid for user KatEvolved.
# 	-Completed getting all current patch Match IDs for user KatEvolved
# 	-There are 10 users left.
# 	-Completed 10 Match IDs for user KatEvolved
#
# Beginning Loop for user Le Sontofukimchi
# 	-Got the puuid for user Le Sontofukimchi.
# 	-Completed getting all current patch Match IDs for user Le Sontofukimchi
# 	-There are 9 users left.
# 	-Completed 5 Match IDs for user Le Sontofukimchi
#
# Beginning Loop for user Bluster2
# 	-Got the puuid for user Bluster2.
# 	-Completed getting all current patch Match IDs for user Bluster2
# 	-There are 8 users left.
# 	-Completed 0 Match IDs for user Bluster2
#
# Beginning Loop for user Lusol
# 	-Got the puuid for user Lusol.
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Completed getting all current patch Match IDs for user Lusol
# 	-There are 7 users left.
# 	-Completed 7 Match IDs for user Lusol
#
# Beginning Loop for user Love lnn
# 	-Got the puuid for user Love lnn.
# 	-Completed getting all current patch Match IDs for user Love lnn
# 	-There are 6 users left.
# 	-Completed 1 Match IDs for user Love lnn
#
# Beginning Loop for user MySwordCrimson
# 	-Got the puuid for user MySwordCrimson.
# 	-Completed getting all current patch Match IDs for user MySwordCrimson
# 	-There are 5 users left.
# 	-Completed 10 Match IDs for user MySwordCrimson
#
# Beginning Loop for user Desmiano
# 	-Got the puuid for user Desmiano.
# 	-Completed getting all current patch Match IDs for user Desmiano
# 	-There are 4 users left.
# 	-Completed 8 Match IDs for user Desmiano
#
# Beginning Loop for user Moonbb
# 	-Got the puuid for user Moonbb.
# 	-Completed getting all current patch Match IDs for user Moonbb
# 	-There are 3 users left.
# 	-Completed 0 Match IDs for user Moonbb
#
# Beginning Loop for user rayma
# 	-Got the puuid for user rayma.
# 	-Completed getting all current patch Match IDs for user rayma
# 	-There are 2 users left.
# 	-Completed 4 Match IDs for user rayma
#
# Beginning Loop for user EDG Dior
#
# Hit 100 pulls! Sleeping for 150 seconds.
# Continuing!
#
# 	-Got the puuid for user EDG Dior.
# 	-Completed getting all current patch Match IDs for user EDG Dior
# 	-There are 1 users left.
# 	-Completed 3 Match IDs for user EDG Dior
#
# Beginning Loop for user xWind
# 	-Got the puuid for user xWind.
# 	-Completed getting all current patch Match IDs for user xWind
# 	-There are 0 users left.
# 	-Completed 14 Match IDs for user xWind
#
# Created timeline_data_user_xWind_end_1609.json
# Created other_game_data_user_xWind_end_1609.json
# All users completed! Follow suit.

# %%
df = build_prepared_df(path = './', time = 10)
# Out:
# Skipping: 0 due to <15 min or not classic
# Skipping: 1 due to <15 min or not classic
# Skipping: 2 due to <15 min or not classic
# Finished with: 3 of 249
# Skipping: 4 due to <15 min or not classic
# Skipping: 5 due to <15 min or not classic
# Skipping: 6 due to <15 min or not classic
# Finished with: 7 of 249
# Finished with: 8 of 249
# Finished with: 9 of 249
# Finished with: 10 of 249
# Finished with: 11 of 249
# Finished with: 12 of 249
# Skipping: 13 due to <15 min or not classic
# Skipping: 14 due to <15 min or not classic
# Skipping: 15 due to <15 min or not classic
# Skipping: 16 due to <15 min or not classic
# Finished with: 17 of 249
# Finished with: 18 of 249
# Skipping: 19 due to <15 min or not classic
# Finished with: 20 of 249
# Finished with: 21 of 249
# Finished with: 22 of 249
# Finished with: 23 of 249
# Finished with: 24 of 249
# Finished with: 25 of 249
# Finished with: 26 of 249
# Finished with: 27 of 249
# Finished with: 28 of 249
# Skipping: 29 due to <15 min or not classic
# Skipping: 30 due to <15 min or not classic
# Skipping: 31 due to <15 min or not classic
# Skipping: 32 due to <15 min or not classic
# Skipping: 33 due to <15 min or not classic
# Skipping: 34 due to <15 min or not classic
# Skipping: 35 due to <15 min or not classic
# Skipping: 36 due to <15 min or not classic
# Finished with: 37 of 249
# Skipping: 38 due to <15 min or not classic
# Finished with: 39 of 249
# Skipping: 40 due to <15 min or not classic
# Skipping: 41 due to <15 min or not classic
# Skipping: 42 due to <15 min or not classic
# Skipping: 43 due to <15 min or not classic
# Skipping: 44 due to <15 min or not classic
# Skipping: 45 due to <15 min or not classic
# Finished with: 46 of 249
# Finished with: 47 of 249
# Skipping: 48 due to <15 min or not classic
# Finished with: 49 of 249
# Finished with: 50 of 249
# Finished with: 51 of 249
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-13c45e58ea4a> in <module>
# ----> 1 df = build_prepared_df(path = './', time = 10)
#
# ~/eSport-Analysis-League-of-Legends/chavez/files/acquire.py in build_prepared_df(path, time)
#     535
#     536         #Now feed them into Joshua C's prepare file. Extract data at the 15 minute mark
# --> 537         temp_df = extract(timeline_list, game_list, 15)
#     538
#     539         #Now prepare the data
#
# ~/eSport-Analysis-League-of-Legends/chavez/files/acquire.py in extract(timeline_data, other_game_data, time)
#      30
#      31             # Using timeline data to extract events, up to a specific time, and add them up to create totals
# ---> 32             kda = get_player_kda(timedata, time)
#      33
#      34             # Saving totals (kda) to final_d
#
# ~/eSport-Analysis-League-of-Legends/chavez/files/acquire.py in get_player_kda(data, time)
#     173         for event in data['info']['frames'][index]['events']:
#     174             if event['type'] == 'WARD_PLACED':
# --> 175                 df = df.append(event, ignore_index =True)
#     176
#     177     kills_df = df[df.type == 'WARD_PLACED']
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7958                 combined_columns = self.columns.astype(object).append(idx_diff)
#    7959             other = (
# -> 7960                 other.reindex(combined_columns, copy=False)
#    7961                 .to_frame()
#    7962                 .T.infer_objects()
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in T(self)
#    2927     @property
#    2928     def T(self) -> DataFrame:
# -> 2929         return self.transpose()
#    2930
#    2931     # ----------------------------------------------------------------------
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in transpose(self, copy, *args)
#    2919             if copy:
#    2920                 new_values = new_values.copy()
# -> 2921             result = self._constructor(
#    2922                 new_values, index=self.columns, columns=self.index
#    2923             )
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     556                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     557             else:
# --> 558                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     559
#     560         # For data is list-like, or Iterable (will consume into list)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in init_ndarray(values, index, columns, dtype, copy)
#     236         block_values = [values]
#     237
# --> 238     return create_block_manager_from_blocks(block_values, [columns, index])
#     239
#     240
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1679
#    1680         mgr = BlockManager(blocks, axes)
# -> 1681         mgr._consolidate_inplace()
#    1682         return mgr
#    1683
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in _consolidate_inplace(self)
#     991     def _consolidate_inplace(self) -> None:
#     992         if not self.is_consolidated():
# --> 993             self.blocks = tuple(_consolidate(self.blocks))
#     994             self._is_consolidated = True
#     995             self._known_consolidated = True
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in _consolidate(blocks)
#    1914     new_blocks: List[Block] = []
#    1915     for (_can_consolidate, dtype), group_blocks in grouper:
# -> 1916         merged_blocks = _merge_blocks(
#    1917             list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    1918         )
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in _merge_blocks(blocks, dtype, can_consolidate)
#    1943         new_mgr_locs = new_mgr_locs[argsort]
#    1944
# -> 1945         return [make_block(new_values, placement=new_mgr_locs, ndim=2)]
#    1946
#    1947     # can't consolidate --> no merge
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2733     if klass is None:
#    2734         dtype = dtype or values.dtype
# -> 2735         klass = get_block_type(values, dtype)
#    2736
#    2737     elif klass is DatetimeTZBlock and not is_datetime64tz_dtype(values.dtype):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in get_block_type(values, dtype)
#    2698     elif is_datetime64tz_dtype(values.dtype):
#    2699         cls = DatetimeTZBlock
# -> 2700     elif is_interval_dtype(dtype) or is_period_dtype(dtype):
#    2701         cls = ObjectValuesExtensionBlock
#    2702     elif is_extension_array_dtype(values.dtype):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/common.py in is_period_dtype(arr_or_dtype)
#     494     if arr_or_dtype is None:
#     495         return False
# --> 496     return PeriodDtype.is_dtype(arr_or_dtype)
#     497
#     498
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/dtypes.py in is_dtype(cls, dtype)
#     940             else:
#     941                 return False
# --> 942         return super().is_dtype(dtype)
#     943
#     944     @classmethod
#
# KeyboardInterrupt:

# %%
df.to_csv('min_10_start_1500_end_1515_.csv')
