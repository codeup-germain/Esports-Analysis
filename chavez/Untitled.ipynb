# %% [markdown]
# # Grabbing timeline and game data

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from env import api_key

# %%
response = requests.get(f"https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name/battlebud?api_key={api_key}")

# %%
response.json()
# Out:
# {'id': 'wPW6si6_BrV_OC4FTi49Si2PeMbJM-7i2y2NK8tcxORSD1k',
#  'accountId': 'pRGmYwVwYy0VU1W-PRfMY_tUuwY6TikHV1clTFR-L1Jrgg',
#  'puuid': 'r9_mZslFIqwPMNiko362SeuZS7luHTEXapN_F-hpJv15KjtDipl4Z_b-YD2Mu6FvcI85MswOCXhW7A',
#  'name': 'Battlebud',
#  'profileIconId': 4404,
#  'revisionDate': 1637333407000,
#  'summonerLevel': 316}

# %%
{'id': 'wPW6si6_BrV_OC4FTi49Si2PeMbJM-7i2y2NK8tcxORSD1k',
 'accountId': 'pRGmYwVwYy0VU1W-PRfMY_tUuwY6TikHV1clTFR-L1Jrgg',
 'puuid': 'r9_mZslFIqwPMNiko362SeuZS7luHTEXapN_F-hpJv15KjtDipl4Z_b-YD2Mu6FvcI85MswOCXhW7A',
 'name': 'Battlebud',
 'profileIconId': 4404,
 'revisionDate': 1637333407000,
 'summonerLevel': 316}
# Out:
# {'id': 'wPW6si6_BrV_OC4FTi49Si2PeMbJM-7i2y2NK8tcxORSD1k',
#  'accountId': 'pRGmYwVwYy0VU1W-PRfMY_tUuwY6TikHV1clTFR-L1Jrgg',
#  'puuid': 'r9_mZslFIqwPMNiko362SeuZS7luHTEXapN_F-hpJv15KjtDipl4Z_b-YD2Mu6FvcI85MswOCXhW7A',
#  'name': 'Battlebud',
#  'profileIconId': 4404,
#  'revisionDate': 1637333407000,
#  'summonerLevel': 316}

# %%
game = 'NA1_3934226831'
url = 'https://americas.api.riotgames.com/'
query = f'lol/match/v5/matches/{game}/timeline?api_key={api_key}'
response = requests.get(url+query)

# %%
response.json()
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'NA1_3934226831',
#   'participants': ['OZ_jGXzPK4m9jsJxVGgFQE3b-cT6ubn_jQLK_bz09t_xgsE6WtRWhrcVdoTNU2mG185XpglkEXoESQ',
#    'ut_x8efoG5cRpG5ylfFkgqI8nzHh5DP26sXrMp_23rxqiRjyv--yJLrFIpGJnPt-o5oAyDcYEA6kVA',
#    'kYoer-Yxm57chCvbeqbVMScBoeS-X4BYEUfadVBkT6Su_0w7OD5SAFvX2sEYan5uxsMWOHbuh-kaXA',
#    'O5kghYbi_AaUD2Ik61AvwjXM77Qp0zyqO5SyQg5ySclWdGwa3TNgdVC8jO8EgLE0zo4TOmGPoIG1Fw',
#    'r9_mZslFIqwPMNiko362SeuZS7luHTEXapN_F-hpJv15KjtDipl4Z_b-YD2Mu6FvcI85MswOCXhW7A',
#    '0HQJ8mCrg5lvbYfx_Vgf_TFimuYKCQeKRKh5bDLYvTbGUgM7y4dj3U5sApKi9y4_r8v5rTJ0KjuEbg',
#    '-bj1j_k29eF1uHNweX5xidFXmXU9i8d5pXLoDeMhFMPcn1Qyp6mH5bBW20z_T4R_-bXc9yfDWNwF1Q',
#    'qivIPQ8d-QzvDUYW5PLaVzHwuz8WOu9reCkC6mbAxwfdycw5htjTLi-ll2i3yK3mX0PhB86f1o8K8Q',
#    'rqijjUkx4AhCc5PAaUGobs0B-VzySsLh8p5Wq9sWZY5pvD7oIkoOZDWXq-B0zFDCQ-QUEXmpU19BaQ',
#    'v_cqw8qSe6DNaydGhtGkRmEnNUH_EnQmEuRQbg_E2cTgSne_0TDaU9xKZFk9m-1utO7ip2P1o_Kd5w']},
#  'info': {'frameInterval': 60000,
#   'frames': [{'events': [{'realTimestamp': 1622987094096,
#       'timestamp': 0,
#       'type': 'PAUSE_END'}],
#     'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 38,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 580,
#        'healthMax': 580,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 345,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 0,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 1,
#       'position': {'x': 554, 'y': 581},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '2': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 30,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 615,
#        'healthMax': 615,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 335,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 285,
#        'powerMax': 285,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 2,
#       'position': {'x': 557, 'y': 345},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '3': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 36,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 580,
#        'healthMax': 580,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 335,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 350,
#        'powerMax': 350,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 3,
#       'position': {'x': 335, 'y': 269},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '4': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 23,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 515,
#        'healthMax': 515,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 330,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 231,
#        'powerMax': 231,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 4,
#       'position': {'x': 194, 'y': 457},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '5': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 45,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 600,
#        'healthMax': 600,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 330,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 415,
#        'powerMax': 415,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 5,
#       'position': {'x': 329, 'y': 650},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '6': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 34,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 561,
#        'healthMax': 561,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 350,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 326,
#        'powerMax': 326,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 6,
#       'position': {'x': 14180, 'y': 14271},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '7': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 33,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 550,
#        'healthMax': 550,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 335,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 280,
#        'powerMax': 280,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 7,
#       'position': {'x': 14176, 'y': 14506},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '8': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 35,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 575,
#        'healthMax': 575,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 345,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 100,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 8,
#       'position': {'x': 14398, 'y': 14582},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '9': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 26,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 530,
#        'healthMax': 530,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 335,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 348,
#        'powerMax': 348,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 9,
#       'position': {'x': 14539, 'y': 14394},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '10': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 22,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 520,
#        'healthMax': 520,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 340,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 469,
#        'powerMax': 469,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 10,
#       'position': {'x': 14404, 'y': 14201},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0}},
#     'timestamp': 0},
#    {'events': [{'itemId': 1055,
#       'participantId': 3,
#       'timestamp': 5622,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 3,
#       'timestamp': 5622,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1035,
#       'participantId': 7,
#       'timestamp': 6315,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3340,
#       'participantId': 3,
#       'timestamp': 6348,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 7,
#       'timestamp': 6976,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1055,
#       'participantId': 4,
#       'timestamp': 7108,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 4,
#       'timestamp': 7108,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3340,
#       'participantId': 4,
#       'timestamp': 8066,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1055,
#       'participantId': 8,
#       'timestamp': 10476,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 8,
#       'timestamp': 10476,
#       'type': 'ITEM_PURCHASED'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 3,
#       'skillSlot': 1,
#       'timestamp': 11038,
#       'type': 'SKILL_LEVEL_UP'},
#      {'itemId': 3340,
#       'participantId': 8,
#       'timestamp': 11434,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1039,
#       'participantId': 2,
#       'timestamp': 11896,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1054,
#       'participantId': 1,
#       'timestamp': 11896,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 1,
#       'timestamp': 11896,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2031,
#       'participantId': 2,
#       'timestamp': 12823,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3340,
#       'participantId': 2,
#       'timestamp': 13285,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1055,
#       'participantId': 9,
#       'timestamp': 14606,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 9,
#       'timestamp': 14606,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3340,
#       'participantId': 9,
#       'timestamp': 15531,
#       'type': 'ITEM_PURCHASED'},
#      {'afterId': 0,
#       'beforeId': 2003,
#       'goldGain': 50,
#       'participantId': 1,
#       'timestamp': 16588,
#       'type': 'ITEM_UNDO'},
#      {'afterId': 0,
#       'beforeId': 1054,
#       'goldGain': 450,
#       'participantId': 1,
#       'timestamp': 16720,
#       'type': 'ITEM_UNDO'},
#      {'itemId': 1055,
#       'participantId': 1,
#       'timestamp': 18107,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 1,
#       'timestamp': 18107,
#       'type': 'ITEM_PURCHASED'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 2,
#       'skillSlot': 2,
#       'timestamp': 18504,
#       'type': 'SKILL_LEVEL_UP'},
#      {'itemId': 3854,
#       'participantId': 5,
#       'timestamp': 18835,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 5,
#       'timestamp': 18835,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 5,
#       'timestamp': 18835,
#       'type': 'ITEM_PURCHASED'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 8,
#       'skillSlot': 1,
#       'timestamp': 19198,
#       'type': 'SKILL_LEVEL_UP'},
#      {'itemId': 3340,
#       'participantId': 5,
#       'timestamp': 19925,
#       'type': 'ITEM_PURCHASED'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 4,
#       'skillSlot': 1,
#       'timestamp': 22237,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 5,
#       'skillSlot': 1,
#       'timestamp': 24550,
#       'type': 'SKILL_LEVEL_UP'},
#      {'creatorId': 2,
#       'timestamp': 31122,
#       'type': 'WARD_PLACED',
#       'wardType': 'YELLOW_TRINKET'},
#      {'itemId': 1054,
#       'participantId': 6,
#       'timestamp': 31716,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 6,
#       'timestamp': 31716,
#       'type': 'ITEM_PURCHASED'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 10,
#       'skillSlot': 2,
#       'timestamp': 33830,
#       'type': 'SKILL_LEVEL_UP'},
#      {'itemId': 3850,
#       'participantId': 10,
#       'timestamp': 35085,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 10,
#       'timestamp': 35085,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 10,
#       'timestamp': 35085,
#       'type': 'ITEM_PURCHASED'},
#      {'creatorId': 4,
#       'timestamp': 41756,
#       'type': 'WARD_PLACED',
#       'wardType': 'YELLOW_TRINKET'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 9,
#       'skillSlot': 1,
#       'timestamp': 48129,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 1,
#       'skillSlot': 1,
#       'timestamp': 51466,
#       'type': 'SKILL_LEVEL_UP'}],
#     'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 44,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 78,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 5,
#        'cooldownReduction': 0,
#        'health': 660,
#        'healthMax': 660,
#        'healthRegen': 6,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 345,
#        'omnivamp': 2,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 0,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 0,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 1,
#       'position': {'x': 1437, 'y': 10384},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '2': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 9,
#        'armor': 36,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 53,
#        'attackSpeed': 110,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 5,
#        'cooldownReduction': 0,
#        'health': 615,
#        'healthMax': 615,
#        'healthRegen': 18,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 335,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 281,
#        'powerMax': 285,
#        'powerRegen': 16,
#        'spellVamp': 0},
#       'currentGold': 0,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 2,
#       'position': {'x': 7721, 'y': 4763},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '3': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 42,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 78,
#        'attackSpeed': 113,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 660,
#        'healthMax': 660,
#        'healthRegen': 17,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 335,
#        'omnivamp': 2,
#        'physicalVamp': 0,
#        'power': 350,
#        'powerMax': 350,
#        'powerRegen': 16,
#        'spellVamp': 0},
#       'currentGold': 0,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 3,
#       'position': {'x': 5074, 'y': 8454},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '4': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 29,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 73,
#        'attackSpeed': 113,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 595,
#        'healthMax': 595,
#        'healthRegen': 7,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 330,
#        'omnivamp': 2,
#        'physicalVamp': 0,
#        'power': 231,
#        'powerMax': 231,
#        'powerRegen': 13,
#        'spellVamp': 0},
#       'currentGold': 0,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 4,
#       'position': {'x': 9354, 'y': 2182},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '5': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 51,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 77,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 10,
#        'cooldownReduction': 0,
#        'health': 600,
#        'healthMax': 600,
#        'healthRegen': 17,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 335,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 415,
#        'powerMax': 415,
#        'powerRegen': 16,
#        'spellVamp': 0},
#       'currentGold': 0,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 20,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 5,
#       'position': {'x': 8558, 'y': 4765},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '6': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 46,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 67,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 641,
#        'healthMax': 641,
#        'healthRegen': 30,
#        'lifesteal': 12,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 350,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 326,
#        'powerMax': 326,
#        'powerRegen': 14,
#        'spellVamp': 0},
#       'currentGold': 0,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 6,
#       'position': {'x': 4690, 'y': 11986},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '7': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 33,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 73,
#        'attackSpeed': 113,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 565,
#        'healthMax': 565,
#        'healthRegen': 8,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 360,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 280,
#        'powerMax': 280,
#        'powerRegen': 14,
#        'spellVamp': 0},
#       'currentGold': 100,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 7,
#       'position': {'x': 8698, 'y': 6730},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '8': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 41,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 87,
#        'attackSpeed': 103,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 655,
#        'healthMax': 655,
#        'healthRegen': 16,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 345,
#        'omnivamp': 2,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 100,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 0,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 8,
#       'position': {'x': 9845, 'y': 6503},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '9': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 32,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 70,
#        'attackSpeed': 110,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 610,
#        'healthMax': 610,
#        'healthRegen': 6,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 335,
#        'omnivamp': 2,
#        'physicalVamp': 0,
#        'power': 348,
#        'powerMax': 348,
#        'powerRegen': 16,
#        'spellVamp': 0},
#       'currentGold': 0,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 9,
#       'position': {'x': 13115, 'y': 7048},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '10': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 26,
#        'armor': 28,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 57,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 530,
#        'healthMax': 530,
#        'healthRegen': 11,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 340,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 469,
#        'powerMax': 469,
#        'powerRegen': 32,
#        'spellVamp': 0},
#       'currentGold': 0,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 20,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 10,
#       'position': {'x': 11810, 'y': 5836},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0}},
#     'timestamp': 60021},
#    {'events': [{'creatorId': 3,
#       'timestamp': 70034,
#       'type': 'WARD_PLACED',
#       'wardType': 'YELLOW_TRINKET'},
#      {'creatorId': 8,
#       'timestamp': 74660,
#       'type': 'WARD_PLACED',
#       'wardType': 'YELLOW_TRINKET'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 7,
#       'skillSlot': 1,
#       'timestamp': 90380,
#       'type': 'SKILL_LEVEL_UP'},
#      {'level': 2, 'participantId': 2, 'timestamp': 105179, 'type': 'LEVEL_UP'},
#      {'level': 2, 'participantId': 7, 'timestamp': 105873, 'type': 'LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 2,
#       'skillSlot': 3,
#       'timestamp': 107194,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 7,
#       'skillSlot': 2,
#       'timestamp': 107920,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 6,
#       'skillSlot': 1,
#       'timestamp': 107953,
#       'type': 'SKILL_LEVEL_UP'},
#      {'bounty': 400,
#       'killStreakLength': 0,
#       'killerId': 3,
#       'position': {'x': 8216, 'y': 8032},
#       'timestamp': 118225,
#       'type': 'CHAMPION_KILL',
#       'victimDamageDealt': [{'basic': False,
#         'magicDamage': 0,
#         'name': 'Renekton',
#         'participantId': 3,
#         'physicalDamage': 56,
#         'spellName': 'renektoncleave',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'Renekton',
#         'participantId': 3,
#         'physicalDamage': 201,
#         'spellName': 'renektonbasicattack2',
#         'spellSlot': 65,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'Renekton',
#         'participantId': 3,
#         'physicalDamage': 68,
#         'spellName': 'renektonbasicattack',
#         'spellSlot': 64,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'Renekton',
#         'participantId': 3,
#         'physicalDamage': 31,
#         'spellName': '',
#         'spellSlot': -1,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'Renekton',
#         'participantId': 3,
#         'physicalDamage': 0,
#         'spellName': 'summonerdot',
#         'spellSlot': 5,
#         'trueDamage': 14,
#         'type': 'OTHER'}],
#       'victimDamageReceived': [{'basic': True,
#         'magicDamage': 0,
#         'name': 'SRU_OrderMinionRanged',
#         'participantId': 0,
#         'physicalDamage': 34,
#         'spellName': 'sru_orderminionrangedbasicattack',
#         'spellSlot': 64,
#         'trueDamage': 0,
#         'type': 'MINION'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'SRU_OrderMinionRanged',
#         'participantId': 0,
#         'physicalDamage': 25,
#         'spellName': 'sru_orderminionrangedbasicattack2',
#         'spellSlot': 65,
#         'trueDamage': 0,
#         'type': 'MINION'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'Irelia',
#         'participantId': 3,
#         'physicalDamage': 405,
#         'spellName': 'ireliabasicattack',
#         'spellSlot': 64,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 130,
#         'name': 'Irelia',
#         'participantId': 3,
#         'physicalDamage': 0,
#         'spellName': 'ireliapassive',
#         'spellSlot': 63,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'Irelia',
#         'participantId': 3,
#         'physicalDamage': 65,
#         'spellName': 'ireliaq',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'Irelia',
#         'participantId': 3,
#         'physicalDamage': 42,
#         'spellName': 'ireliaq',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'Irelia',
#         'participantId': 3,
#         'physicalDamage': 0,
#         'spellName': 'summonerdot',
#         'spellSlot': 5,
#         'trueDamage': 14,
#         'type': 'OTHER'}],
#       'victimId': 8},
#      {'killType': 'KILL_FIRST_BLOOD',
#       'killerId': 3,
#       'position': {'x': 8056, 'y': 7982},
#       'timestamp': 118225,
#       'type': 'CHAMPION_SPECIAL_KILL'},
#      {'level': 2, 'participantId': 3, 'timestamp': 118225, 'type': 'LEVEL_UP'},
#      {'creatorId': 7,
#       'timestamp': 118390,
#       'type': 'WARD_PLACED',
#       'wardType': 'UNDEFINED'}],
#     'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 44,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 78,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 5,
#        'cooldownReduction': 0,
#        'health': 647,
#        'healthMax': 660,
#        'healthRegen': 6,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 345,
#        'omnivamp': 2,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 0,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 84,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 260,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 16,
#        'totalDamageDone': 260,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 16,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 3,
#       'participantId': 1,
#       'position': {'x': 2180, 'y': 12304},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 584,
#       'xp': 181},
#      '2': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 9,
#        'armor': 38,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 55,
#        'attackSpeed': 111,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 5,
#        'cooldownReduction': 0,
#        'health': 418,
#        'healthMax': 672,
#        'healthRegen': 136,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 335,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 203,
#        'powerMax': 313,
#        'powerRegen': 55,
#        'spellVamp': 0},
#       'currentGold': 121,
#       'damageStats': {'magicDamageDone': 1009,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 855,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 732,
#        'totalDamageDone': 2000,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 732,
#        'trueDamageDone': 136,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 4,
#       'level': 2,
#       'minionsKilled': 0,
#       'participantId': 2,
#       'position': {'x': 8399, 'y': 2779},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 621,
#       'xp': 320},
#      '3': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 44,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 95,
#        'attackSpeed': 156,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 313,
#        'healthMax': 728,
#        'healthRegen': 7,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 335,
#        'omnivamp': 2,
#        'physicalVamp': 0,
#        'power': 301,
#        'powerMax': 386,
#        'powerRegen': 17,
#        'spellVamp': 0},
#       'currentGold': 532,
#       'damageStats': {'magicDamageDone': 155,
#        'magicDamageDoneToChampions': 130,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 1850,
#        'physicalDamageDoneToChampions': 513,
#        'physicalDamageTaken': 494,
#        'totalDamageDone': 2019,
#        'totalDamageDoneToChampions': 658,
#        'totalDamageTaken': 522,
#        'trueDamageDone': 14,
#        'trueDamageDoneToChampions': 14,
#        'trueDamageTaken': 28},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 2,
#       'minionsKilled': 5,
#       'participantId': 3,
#       'position': {'x': 7844, 'y': 7800},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 1032,
#       'xp': 282},
#      '4': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 29,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 73,
#        'attackSpeed': 113,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 510,
#        'healthMax': 595,
#        'healthRegen': 7,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 360,
#        'omnivamp': 2,
#        'physicalVamp': 0,
#        'power': 182,
#        'powerMax': 231,
#        'powerRegen': 13,
#        'spellVamp': 0},
#       'currentGold': 63,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 85,
#        'physicalDamageDone': 526,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 526,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 85,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 2,
#       'participantId': 4,
#       'position': {'x': 12043, 'y': 2236},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 563,
#       'xp': 113},
#      '5': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 51,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 77,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 10,
#        'cooldownReduction': 0,
#        'health': 600,
#        'healthMax': 600,
#        'healthRegen': 17,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 335,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 411,
#        'powerMax': 415,
#        'powerRegen': 16,
#        'spellVamp': 0},
#       'currentGold': 23,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 468,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 468,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 20,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 5,
#       'position': {'x': 12135, 'y': 1758},
#       'timeEnemySpentControlled': 2047,
#       'totalGold': 523,
#       'xp': 113},
#      '6': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 46,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 67,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 641,
#        'healthMax': 641,
#        'healthRegen': 30,
#        'lifesteal': 12,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 350,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 300,
#        'powerMax': 326,
#        'powerRegen': 14,
#        'spellVamp': 0},
#       'currentGold': 63,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 246,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 246,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 2,
#       'participantId': 6,
#       'position': {'x': 2324, 'y': 12549},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 563,
#       'xp': 181},
#      '7': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 35,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 72,
#        'attackSpeed': 184,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 335,
#        'healthMax': 630,
#        'healthRegen': 9,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 335,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 269,
#        'powerMax': 305,
#        'powerRegen': 111,
#        'spellVamp': 0},
#       'currentGold': 221,
#       'damageStats': {'magicDamageDone': 1352,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 352,
#        'physicalDamageDone': 1189,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 410,
#        'totalDamageDone': 2542,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 762,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 4,
#       'level': 2,
#       'minionsKilled': 0,
#       'participantId': 7,
#       'position': {'x': 12042, 'y': 6947},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 621,
#       'xp': 320},
#      '8': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 41,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 87,
#        'attackSpeed': 103,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 0,
#        'healthMax': 655,
#        'healthRegen': 16,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 345,
#        'omnivamp': 2,
#        'physicalVamp': 0,
#        'power': 82,
#        'powerMax': 100,
#        'powerRegen': 0,
#        'spellVamp': 0},
# ...
#       'timestamp': 1793783,
#       'type': 'ITEM_DESTROYED'},
#      {'itemId': 1037,
#       'participantId': 5,
#       'timestamp': 1793783,
#       'type': 'ITEM_DESTROYED'},
#      {'itemId': 3142,
#       'participantId': 5,
#       'timestamp': 1793783,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2055,
#       'participantId': 1,
#       'timestamp': 1794047,
#       'type': 'ITEM_PURCHASED'},
#      {'gameId': 3934226831,
#       'realTimestamp': 1622988893808,
#       'timestamp': 1799529,
#       'type': 'GAME_END',
#       'winningTeam': 200}],
#     'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 111,
#        'armorPen': 0,
#        'armorPenPercent': 8,
#        'attackDamage': 313,
#        'attackSpeed': 136,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 30,
#        'cooldownReduction': 0,
#        'health': 177,
#        'healthMax': 2537,
#        'healthRegen': 34,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 50,
#        'movementSpeed': 390,
#        'omnivamp': 10,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 0,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 59,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 8861,
#        'physicalDamageDone': 125718,
#        'physicalDamageDoneToChampions': 21913,
#        'physicalDamageTaken': 16194,
#        'totalDamageDone': 130793,
#        'totalDamageDoneToChampions': 22028,
#        'totalDamageTaken': 25857,
#        'trueDamageDone': 5075,
#        'trueDamageDoneToChampions': 115,
#        'trueDamageTaken': 801},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 10,
#       'level': 16,
#       'minionsKilled': 178,
#       'participantId': 1,
#       'position': {'x': 9661, 'y': 2438},
#       'timeEnemySpentControlled': 223980,
#       'totalGold': 10613,
#       'xp': 15464},
#      '2': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 50,
#        'armor': 191,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 102,
#        'attackSpeed': 136,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 33,
#        'cooldownReduction': 0,
#        'health': 0,
#        'healthMax': 2632,
#        'healthRegen': 38,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 77,
#        'movementSpeed': 380,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 543,
#        'powerMax': 768,
#        'powerRegen': 88,
#        'spellVamp': 0},
#       'currentGold': 501,
#       'damageStats': {'magicDamageDone': 85192,
#        'magicDamageDoneToChampions': 12641,
#        'magicDamageTaken': 11576,
#        'physicalDamageDone': 19452,
#        'physicalDamageDoneToChampions': 1418,
#        'physicalDamageTaken': 12008,
#        'totalDamageDone': 123123,
#        'totalDamageDoneToChampions': 16090,
#        'totalDamageTaken': 24379,
#        'trueDamageDone': 18479,
#        'trueDamageDoneToChampions': 2030,
#        'trueDamageTaken': 795},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 112,
#       'level': 14,
#       'minionsKilled': 23,
#       'participantId': 2,
#       'position': {'x': 9482, 'y': 5381},
#       'timeEnemySpentControlled': 206408,
#       'totalGold': 10211,
#       'xp': 12760},
#      '3': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 146,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 303,
#        'attackSpeed': 206,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 0,
#        'healthMax': 2020,
#        'healthRegen': 39,
#        'lifesteal': 20,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 48,
#        'movementSpeed': 380,
#        'omnivamp': 2,
#        'physicalVamp': 0,
#        'power': 567,
#        'powerMax': 1013,
#        'powerRegen': 37,
#        'spellVamp': 0},
#       'currentGold': 135,
#       'damageStats': {'magicDamageDone': 17297,
#        'magicDamageDoneToChampions': 6494,
#        'magicDamageTaken': 8350,
#        'physicalDamageDone': 100762,
#        'physicalDamageDoneToChampions': 12939,
#        'physicalDamageTaken': 19106,
#        'totalDamageDone': 140259,
#        'totalDamageDoneToChampions': 21321,
#        'totalDamageTaken': 27864,
#        'trueDamageDone': 22199,
#        'trueDamageDoneToChampions': 1887,
#        'trueDamageTaken': 407},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 15,
#       'minionsKilled': 167,
#       'participantId': 3,
#       'position': {'x': 11072, 'y': 4280},
#       'timeEnemySpentControlled': 58179,
#       'totalGold': 11560,
#       'xp': 13261},
#      '4': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 70,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 215,
#        'attackSpeed': 317,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 0,
#        'healthMax': 1671,
#        'healthRegen': 20,
#        'lifesteal': 10,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 36,
#        'movementSpeed': 375,
#        'omnivamp': 2,
#        'physicalVamp': 0,
#        'power': 467,
#        'powerMax': 654,
#        'powerRegen': 23,
#        'spellVamp': 0},
#       'currentGold': 801,
#       'damageStats': {'magicDamageDone': 80,
#        'magicDamageDoneToChampions': 80,
#        'magicDamageTaken': 7448,
#        'physicalDamageDone': 77134,
#        'physicalDamageDoneToChampions': 12647,
#        'physicalDamageTaken': 13354,
#        'totalDamageDone': 99462,
#        'totalDamageDoneToChampions': 17394,
#        'totalDamageTaken': 21125,
#        'trueDamageDone': 22248,
#        'trueDamageDoneToChampions': 4666,
#        'trueDamageTaken': 322},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 8,
#       'level': 14,
#       'minionsKilled': 153,
#       'participantId': 4,
#       'position': {'x': 10691, 'y': 4860},
#       'timeEnemySpentControlled': 11493,
#       'totalGold': 11776,
#       'xp': 12633},
#      '5': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 89,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 315,
#        'attackSpeed': 127,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 30,
#        'cooldownReduction': 0,
#        'health': 0,
#        'healthMax': 1585,
#        'healthRegen': 49,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 45,
#        'movementSpeed': 495,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 457,
#        'powerMax': 962,
#        'powerRegen': 37,
#        'spellVamp': 0},
#       'currentGold': 646,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 8225,
#        'physicalDamageDone': 23101,
#        'physicalDamageDoneToChampions': 8974,
#        'physicalDamageTaken': 10598,
#        'totalDamageDone': 33035,
#        'totalDamageDoneToChampions': 11511,
#        'totalDamageTaken': 19103,
#        'trueDamageDone': 9933,
#        'trueDamageDoneToChampions': 2536,
#        'trueDamageTaken': 279},
#       'goldPerSecond': 30,
#       'jungleMinionsKilled': 0,
#       'level': 13,
#       'minionsKilled': 33,
#       'participantId': 5,
#       'position': {'x': 11024, 'y': 4092},
#       'timeEnemySpentControlled': 115301,
#       'totalGold': 11096,
#       'xp': 10175},
#      '6': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 327,
#        'armorPen': 0,
#        'armorPenPercent': 10,
#        'attackDamage': 153,
#        'attackSpeed': 146,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 0,
#        'healthMax': 2654,
#        'healthRegen': 41,
#        'lifesteal': 24,
#        'magicPen': 0,
#        'magicPenPercent': 10,
#        'magicResist': 54,
#        'movementSpeed': 405,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 1506,
#        'powerMax': 1698,
#        'powerRegen': 28,
#        'spellVamp': 0},
#       'currentGold': 266,
#       'damageStats': {'magicDamageDone': 9457,
#        'magicDamageDoneToChampions': 4368,
#        'magicDamageTaken': 4394,
#        'physicalDamageDone': 111997,
#        'physicalDamageDoneToChampions': 11099,
#        'physicalDamageTaken': 24205,
#        'totalDamageDone': 123345,
#        'totalDamageDoneToChampions': 15818,
#        'totalDamageTaken': 32431,
#        'trueDamageDone': 1890,
#        'trueDamageDoneToChampions': 350,
#        'trueDamageTaken': 3830},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 4,
#       'level': 15,
#       'minionsKilled': 170,
#       'participantId': 6,
#       'position': {'x': 10969, 'y': 4424},
#       'timeEnemySpentControlled': 184369,
#       'totalGold': 11371,
#       'xp': 14485},
#      '7': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 207,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 165,
#        'attackSpeed': 158,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 10,
#        'cooldownReduction': 0,
#        'health': 0,
#        'healthMax': 2954,
#        'healthRegen': 27,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 88,
#        'movementSpeed': 380,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 403,
#        'powerMax': 744,
#        'powerRegen': 128,
#        'spellVamp': 0},
#       'currentGold': 125,
#       'damageStats': {'magicDamageDone': 63458,
#        'magicDamageDoneToChampions': 10710,
#        'magicDamageTaken': 5805,
#        'physicalDamageDone': 67836,
#        'physicalDamageDoneToChampions': 4786,
#        'physicalDamageTaken': 28457,
#        'totalDamageDone': 143723,
#        'totalDamageDoneToChampions': 16394,
#        'totalDamageTaken': 35546,
#        'trueDamageDone': 12429,
#        'trueDamageDoneToChampions': 897,
#        'trueDamageTaken': 1283},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 152,
#       'level': 15,
#       'minionsKilled': 9,
#       'participantId': 7,
#       'position': {'x': 10631, 'y': 2332},
#       'timeEnemySpentControlled': 215098,
#       'totalGold': 11050,
#       'xp': 14233},
#      '8': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 217,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 284,
#        'attackSpeed': 177,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 1744,
#        'healthMax': 2434,
#        'healthRegen': 37,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 56,
#        'movementSpeed': 413,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 11,
#        'powerMax': 100,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 1496,
#       'damageStats': {'magicDamageDone': 2914,
#        'magicDamageDoneToChampions': 1989,
#        'magicDamageTaken': 7836,
#        'physicalDamageDone': 102382,
#        'physicalDamageDoneToChampions': 19509,
#        'physicalDamageTaken': 13340,
#        'totalDamageDone': 106284,
#        'totalDamageDoneToChampions': 22487,
#        'totalDamageTaken': 23546,
#        'trueDamageDone': 988,
#        'trueDamageDoneToChampions': 988,
#        'trueDamageTaken': 2369},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 16,
#       'minionsKilled': 166,
#       'participantId': 8,
#       'position': {'x': 6805, 'y': 1585},
#       'timeEnemySpentControlled': 35676,
#       'totalGold': 13325,
#       'xp': 16223},
#      '9': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 98,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 268,
#        'attackSpeed': 169,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 1643,
#        'healthMax': 1643,
#        'healthRegen': 19,
#        'lifesteal': 29,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 40,
#        'movementSpeed': 380,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 764,
#        'powerMax': 808,
#        'powerRegen': 33,
#        'spellVamp': 0},
#       'currentGold': 1074,
#       'damageStats': {'magicDamageDone': 13249,
#        'magicDamageDoneToChampions': 1637,
#        'magicDamageTaken': 1710,
#        'physicalDamageDone': 101088,
#        'physicalDamageDoneToChampions': 9255,
#        'physicalDamageTaken': 14487,
#        'totalDamageDone': 114595,
#        'totalDamageDoneToChampions': 11150,
#        'totalDamageTaken': 18598,
#        'trueDamageDone': 257,
#        'trueDamageDoneToChampions': 257,
#        'trueDamageTaken': 2401},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 16,
#       'level': 14,
#       'minionsKilled': 174,
#       'participantId': 9,
#       'position': {'x': 2096, 'y': 2505},
#       'timeEnemySpentControlled': 2907,
#       'totalGold': 11784,
#       'xp': 12933},
#      '10': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 333,
#        'armor': 74,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 89,
#        'attackSpeed': 114,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 1147,
#        'healthMax': 1948,
#        'healthRegen': 23,
#        'lifesteal': 0,
#        'magicPen': 18,
#        'magicPenPercent': 0,
#        'magicResist': 39,
#        'movementSpeed': 385,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 1253,
#        'powerMax': 1548,
#        'powerRegen': 68,
#        'spellVamp': 0},
#       'currentGold': 1008,
#       'damageStats': {'magicDamageDone': 73287,
#        'magicDamageDoneToChampions': 22827,
#        'magicDamageTaken': 2139,
#        'physicalDamageDone': 4802,
#        'physicalDamageDoneToChampions': 557,
#        'physicalDamageTaken': 9451,
#        'totalDamageDone': 83301,
#        'totalDamageDoneToChampions': 23496,
#        'totalDamageTaken': 12991,
#        'trueDamageDone': 5211,
#        'trueDamageDoneToChampions': 112,
#        'trueDamageTaken': 1400},
#       'goldPerSecond': 30,
#       'jungleMinionsKilled': 18,
#       'level': 13,
#       'minionsKilled': 44,
#       'participantId': 10,
#       'position': {'x': 5611, 'y': 3587},
#       'timeEnemySpentControlled': 50237,
#       'totalGold': 10458,
#       'xp': 11246}},
#     'timestamp': 1799529}],
#   'gameId': 3934226831,
#   'participants': [{'participantId': 1,
#     'puuid': 'OZ_jGXzPK4m9jsJxVGgFQE3b-cT6ubn_jQLK_bz09t_xgsE6WtRWhrcVdoTNU2mG185XpglkEXoESQ'},
#    {'participantId': 2,
#     'puuid': 'ut_x8efoG5cRpG5ylfFkgqI8nzHh5DP26sXrMp_23rxqiRjyv--yJLrFIpGJnPt-o5oAyDcYEA6kVA'},
#    {'participantId': 3,
#     'puuid': 'kYoer-Yxm57chCvbeqbVMScBoeS-X4BYEUfadVBkT6Su_0w7OD5SAFvX2sEYan5uxsMWOHbuh-kaXA'},
#    {'participantId': 4,
#     'puuid': 'O5kghYbi_AaUD2Ik61AvwjXM77Qp0zyqO5SyQg5ySclWdGwa3TNgdVC8jO8EgLE0zo4TOmGPoIG1Fw'},
#    {'participantId': 5,
#     'puuid': 'r9_mZslFIqwPMNiko362SeuZS7luHTEXapN_F-hpJv15KjtDipl4Z_b-YD2Mu6FvcI85MswOCXhW7A'},
#    {'participantId': 6,
#     'puuid': '0HQJ8mCrg5lvbYfx_Vgf_TFimuYKCQeKRKh5bDLYvTbGUgM7y4dj3U5sApKi9y4_r8v5rTJ0KjuEbg'},
#    {'participantId': 7,
#     'puuid': '-bj1j_k29eF1uHNweX5xidFXmXU9i8d5pXLoDeMhFMPcn1Qyp6mH5bBW20z_T4R_-bXc9yfDWNwF1Q'},
#    {'participantId': 8,
#     'puuid': 'qivIPQ8d-QzvDUYW5PLaVzHwuz8WOu9reCkC6mbAxwfdycw5htjTLi-ll2i3yK3mX0PhB86f1o8K8Q'},
#    {'participantId': 9,
#     'puuid': 'rqijjUkx4AhCc5PAaUGobs0B-VzySsLh8p5Wq9sWZY5pvD7oIkoOZDWXq-B0zFDCQ-QUEXmpU19BaQ'},
#    {'participantId': 10,
#     'puuid': 'v_cqw8qSe6DNaydGhtGkRmEnNUH_EnQmEuRQbg_E2cTgSne_0TDaU9xKZFk9m-1utO7ip2P1o_Kd5w'}]}}
