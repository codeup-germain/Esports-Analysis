# %% [markdown]
# # Grabbing timeline and game data

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from env import api_key

# %%
response = requests.get(f"https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name/battlebud?api_key={api_key}")

# %%
response.json()
# Out:
# {'id': 'wPW6si6_BrV_OC4FTi49Si2PeMbJM-7i2y2NK8tcxORSD1k',
#  'accountId': 'pRGmYwVwYy0VU1W-PRfMY_tUuwY6TikHV1clTFR-L1Jrgg',
#  'puuid': 'r9_mZslFIqwPMNiko362SeuZS7luHTEXapN_F-hpJv15KjtDipl4Z_b-YD2Mu6FvcI85MswOCXhW7A',
#  'name': 'Battlebud',
#  'profileIconId': 4404,
#  'revisionDate': 1637333407000,
#  'summonerLevel': 316}

# %%
{'id': 'wPW6si6_BrV_OC4FTi49Si2PeMbJM-7i2y2NK8tcxORSD1k',
 'accountId': 'pRGmYwVwYy0VU1W-PRfMY_tUuwY6TikHV1clTFR-L1Jrgg',
 'puuid': 'r9_mZslFIqwPMNiko362SeuZS7luHTEXapN_F-hpJv15KjtDipl4Z_b-YD2Mu6FvcI85MswOCXhW7A',
 'name': 'Battlebud',
 'profileIconId': 4404,
 'revisionDate': 1637333407000,
 'summonerLevel': 316}
# Out:
# {'id': 'wPW6si6_BrV_OC4FTi49Si2PeMbJM-7i2y2NK8tcxORSD1k',
#  'accountId': 'pRGmYwVwYy0VU1W-PRfMY_tUuwY6TikHV1clTFR-L1Jrgg',
#  'puuid': 'r9_mZslFIqwPMNiko362SeuZS7luHTEXapN_F-hpJv15KjtDipl4Z_b-YD2Mu6FvcI85MswOCXhW7A',
#  'name': 'Battlebud',
#  'profileIconId': 4404,
#  'revisionDate': 1637333407000,
#  'summonerLevel': 316}

# %%
game = 'NA1_3934226831'
url = 'https://americas.api.riotgames.com/'
query = f'lol/match/v5/matches/{game}?api_key={api_key}'
response = requests.get(url+query)

# %%
response.json()
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'NA1_3934226831',
#   'participants': ['OZ_jGXzPK4m9jsJxVGgFQE3b-cT6ubn_jQLK_bz09t_xgsE6WtRWhrcVdoTNU2mG185XpglkEXoESQ',
#    'ut_x8efoG5cRpG5ylfFkgqI8nzHh5DP26sXrMp_23rxqiRjyv--yJLrFIpGJnPt-o5oAyDcYEA6kVA',
#    'kYoer-Yxm57chCvbeqbVMScBoeS-X4BYEUfadVBkT6Su_0w7OD5SAFvX2sEYan5uxsMWOHbuh-kaXA',
#    'O5kghYbi_AaUD2Ik61AvwjXM77Qp0zyqO5SyQg5ySclWdGwa3TNgdVC8jO8EgLE0zo4TOmGPoIG1Fw',
#    'r9_mZslFIqwPMNiko362SeuZS7luHTEXapN_F-hpJv15KjtDipl4Z_b-YD2Mu6FvcI85MswOCXhW7A',
#    '0HQJ8mCrg5lvbYfx_Vgf_TFimuYKCQeKRKh5bDLYvTbGUgM7y4dj3U5sApKi9y4_r8v5rTJ0KjuEbg',
#    '-bj1j_k29eF1uHNweX5xidFXmXU9i8d5pXLoDeMhFMPcn1Qyp6mH5bBW20z_T4R_-bXc9yfDWNwF1Q',
#    'qivIPQ8d-QzvDUYW5PLaVzHwuz8WOu9reCkC6mbAxwfdycw5htjTLi-ll2i3yK3mX0PhB86f1o8K8Q',
#    'rqijjUkx4AhCc5PAaUGobs0B-VzySsLh8p5Wq9sWZY5pvD7oIkoOZDWXq-B0zFDCQ-QUEXmpU19BaQ',
#    'v_cqw8qSe6DNaydGhtGkRmEnNUH_EnQmEuRQbg_E2cTgSne_0TDaU9xKZFk9m-1utO7ip2P1o_Kd5w']},
#  'info': {'gameCreation': 1622987065000,
#   'gameDuration': 1799613,
#   'gameId': 3934226831,
#   'gameMode': 'CLASSIC',
#   'gameName': 'teambuilder-match-3934226831',
#   'gameStartTimestamp': 1622987094196,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '11.11.377.6311',
#   'mapId': 11,
#   'participants': [{'assists': 6,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 15464,
#     'champLevel': 16,
#     'championId': 266,
#     'championName': 'Aatrox',
#     'championTransform': 0,
#     'consumablesPurchased': 4,
#     'damageDealtToBuildings': 2678,
#     'damageDealtToObjectives': 6480,
#     'damageDealtToTurrets': 2678,
#     'damageSelfMitigated': 21767,
#     'deaths': 5,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 10613,
#     'goldSpent': 10800,
#     'individualPosition': 'TOP',
#     'inhibitorKills': 0,
#     'inhibitorsLost': 1,
#     'item0': 1055,
#     'item1': 3047,
#     'item2': 6692,
#     'item3': 6609,
#     'item4': 3814,
#     'item5': 2055,
#     'item6': 3340,
#     'itemsPurchased': 27,
#     'killingSprees': 1,
#     'kills': 4,
#     'lane': 'TOP',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 615,
#     'magicDamageDealt': 0,
#     'magicDamageDealtToChampions': 0,
#     'magicDamageTaken': 8861,
#     'neutralMinionsKilled': 10,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 318, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 449, 'var2': 200, 'var3': 0},
#         {'perk': 9105, 'var1': 23, 'var2': 0, 'var3': 0},
#         {'perk': 8299, 'var1': 464, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8473, 'var1': 901, 'var2': 0, 'var3': 0},
#         {'perk': 8453, 'var1': 1148, 'var2': 290, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 125718,
#     'physicalDamageDealtToChampions': 21913,
#     'physicalDamageTaken': 16194,
#     'profileIcon': 1637,
#     'puuid': 'OZ_jGXzPK4m9jsJxVGgFQE3b-cT6ubn_jQLK_bz09t_xgsE6WtRWhrcVdoTNU2mG185XpglkEXoESQ',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 190,
#     'spell2Casts': 20,
#     'spell3Casts': 70,
#     'spell4Casts': 8,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 3,
#     'summoner2Id': 12,
#     'summonerId': 'faLQK0VSGocK6cXFi6RhMDwDCqyv9HZh464pbQomZQRtxuc',
#     'summonerLevel': 136,
#     'summonerName': 'SOULN4TION',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'TOP',
#     'timeCCingOthers': 18,
#     'timePlayed': 1799,
#     'totalDamageDealt': 130793,
#     'totalDamageDealtToChampions': 22028,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 25857,
#     'totalHeal': 11942,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 178,
#     'totalTimeCCDealt': 223,
#     'totalTimeSpentDead': 142,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 5075,
#     'trueDamageDealtToChampions': 115,
#     'trueDamageTaken': 801,
#     'turretKills': 0,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionScore': 18,
#     'visionWardsBoughtInGame': 2,
#     'wardsKilled': 1,
#     'wardsPlaced': 10,
#     'win': False},
#    {'assists': 7,
#     'baronKills': 1,
#     'bountyLevel': 0,
#     'champExperience': 12760,
#     'champLevel': 14,
#     'championId': 32,
#     'championName': 'Amumu',
#     'championTransform': 0,
#     'consumablesPurchased': 6,
#     'damageDealtToBuildings': 493,
#     'damageDealtToObjectives': 17537,
#     'damageDealtToTurrets': 493,
#     'damageSelfMitigated': 26922,
#     'deaths': 4,
#     'detectorWardsPlaced': 6,
#     'doubleKills': 0,
#     'dragonKills': 2,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 10211,
#     'goldSpent': 9700,
#     'individualPosition': 'JUNGLE',
#     'inhibitorKills': 0,
#     'inhibitorsLost': 1,
#     'item0': 3075,
#     'item1': 2031,
#     'item2': 3047,
#     'item3': 1026,
#     'item4': 1011,
#     'item5': 3068,
#     'item6': 3364,
#     'itemsPurchased': 26,
#     'killingSprees': 1,
#     'kills': 5,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 15,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 1144,
#     'magicDamageDealt': 85192,
#     'magicDamageDealtToChampions': 12641,
#     'magicDamageTaken': 11576,
#     'neutralMinionsKilled': 112,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 670, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 869, 'var2': 240, 'var3': 0},
#         {'perk': 9105, 'var1': 16, 'var2': 30, 'var3': 0},
#         {'perk': 8299, 'var1': 411, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8126, 'var1': 515, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 1389, 'var2': 5, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 19452,
#     'physicalDamageDealtToChampions': 1418,
#     'physicalDamageTaken': 12008,
#     'profileIcon': 682,
#     'puuid': 'ut_x8efoG5cRpG5ylfFkgqI8nzHh5DP26sXrMp_23rxqiRjyv--yJLrFIpGJnPt-o5oAyDcYEA6kVA',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 47,
#     'spell2Casts': 89,
#     'spell3Casts': 104,
#     'spell4Casts': 9,
#     'summoner1Casts': 4,
#     'summoner1Id': 4,
#     'summoner2Casts': 19,
#     'summoner2Id': 11,
#     'summonerId': 'xq0csMtadg6FAtT1xqi3FPyKxpPJcC466re-dbBmk0xqUFk',
#     'summonerLevel': 315,
#     'summonerName': 'Man Plays Game',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'JUNGLE',
#     'timeCCingOthers': 33,
#     'timePlayed': 1799,
#     'totalDamageDealt': 123123,
#     'totalDamageDealtToChampions': 16090,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 24379,
#     'totalHeal': 7102,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 23,
#     'totalTimeCCDealt': 206,
#     'totalTimeSpentDead': 129,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 18479,
#     'trueDamageDealtToChampions': 2030,
#     'trueDamageTaken': 795,
#     'turretKills': 0,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionScore': 26,
#     'visionWardsBoughtInGame': 6,
#     'wardsKilled': 5,
#     'wardsPlaced': 7,
#     'win': False},
#    {'assists': 10,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 13261,
#     'champLevel': 15,
#     'championId': 39,
#     'championName': 'Irelia',
#     'championTransform': 0,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 735,
#     'damageDealtToObjectives': 3790,
#     'damageDealtToTurrets': 735,
#     'damageSelfMitigated': 22873,
#     'deaths': 11,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': True,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 11560,
#     'goldSpent': 11375,
#     'individualPosition': 'MIDDLE',
#     'inhibitorKills': 0,
#     'inhibitorsLost': 1,
#     'item0': 1055,
#     'item1': 6333,
#     'item2': 0,
#     'item3': 6673,
#     'item4': 3047,
#     'item5': 3153,
#     'item6': 3340,
#     'itemsPurchased': 21,
#     'killingSprees': 0,
#     'kills': 4,
#     'lane': 'MIDDLE',
#     'largestCriticalStrike': 449,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 395,
#     'magicDamageDealt': 17297,
#     'magicDamageDealtToChampions': 6494,
#     'magicDamageTaken': 8350,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 834, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 969, 'var2': 280, 'var3': 0},
#         {'perk': 9104, 'var1': 13, 'var2': 30, 'var3': 0},
#         {'perk': 8299, 'var1': 678, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8473, 'var1': 1097, 'var2': 0, 'var3': 0},
#         {'perk': 8453, 'var1': 1488, 'var2': 260, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 100762,
#     'physicalDamageDealtToChampions': 12939,
#     'physicalDamageTaken': 19106,
#     'profileIcon': 4764,
#     'puuid': 'kYoer-Yxm57chCvbeqbVMScBoeS-X4BYEUfadVBkT6Su_0w7OD5SAFvX2sEYan5uxsMWOHbuh-kaXA',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 172,
#     'spell2Casts': 20,
#     'spell3Casts': 51,
#     'spell4Casts': 8,
#     'summoner1Casts': 4,
#     'summoner1Id': 4,
#     'summoner2Casts': 8,
#     'summoner2Id': 14,
#     'summonerId': 'KQFg6WaRy4D3UkbzqrVJeiC5dAbIPSkG-gUJICPA_6dazcw',
#     'summonerLevel': 209,
#     'summonerName': 'Asuryan',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'MIDDLE',
#     'timeCCingOthers': 12,
#     'timePlayed': 1799,
#     'totalDamageDealt': 140259,
#     'totalDamageDealtToChampions': 21321,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 27864,
#     'totalHeal': 3704,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 167,
#     'totalTimeCCDealt': 58,
#     'totalTimeSpentDead': 304,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 22199,
#     'trueDamageDealtToChampions': 1887,
#     'trueDamageTaken': 407,
#     'turretKills': 0,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionScore': 14,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 0,
#     'wardsPlaced': 10,
#     'win': False},
#    {'assists': 11,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 12633,
#     'champLevel': 14,
#     'championId': 67,
#     'championName': 'Vayne',
#     'championTransform': 0,
#     'consumablesPurchased': 4,
#     'damageDealtToBuildings': 1762,
#     'damageDealtToObjectives': 7046,
#     'damageDealtToTurrets': 1762,
#     'damageSelfMitigated': 8751,
#     'deaths': 9,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 11776,
#     'goldSpent': 10975,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorsLost': 1,
#     'item0': 6672,
#     'item1': 1055,
#     'item2': 3006,
#     'item3': 3124,
#     'item4': 3153,
#     'item5': 0,
#     'item6': 3340,
#     'itemsPurchased': 20,
#     'killingSprees': 1,
#     'kills': 5,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 270,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 488,
#     'magicDamageDealt': 80,
#     'magicDamageDealtToChampions': 80,
#     'magicDamageTaken': 7448,
#     'neutralMinionsKilled': 8,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 4,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8005, 'var1': 916, 'var2': 697, 'var3': 219},
#         {'perk': 9111, 'var1': 515, 'var2': 320, 'var3': 0},
#         {'perk': 9104, 'var1': 18, 'var2': 30, 'var3': 0},
#         {'perk': 8014, 'var1': 322, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8139, 'var1': 882, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 2579, 'var2': 5, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 77134,
#     'physicalDamageDealtToChampions': 12647,
#     'physicalDamageTaken': 13354,
#     'profileIcon': 4760,
#     'puuid': 'O5kghYbi_AaUD2Ik61AvwjXM77Qp0zyqO5SyQg5ySclWdGwa3TNgdVC8jO8EgLE0zo4TOmGPoIG1Fw',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 86,
#     'spell2Casts': 0,
#     'spell3Casts': 11,
#     'spell4Casts': 9,
#     'summoner1Casts': 5,
#     'summoner1Id': 7,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': 'HF8vCNB0zOyG7nKzDAZQiE_xH2LleQMgkvmrO9hoQe_60cI',
#     'summonerLevel': 368,
#     'summonerName': 'Ryuujin Jakka',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 9,
#     'timePlayed': 1799,
#     'totalDamageDealt': 99462,
#     'totalDamageDealtToChampions': 17394,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 21125,
#     'totalHeal': 5718,
#     'totalHealsOnTeammates': 579,
#     'totalMinionsKilled': 153,
#     'totalTimeCCDealt': 11,
#     'totalTimeSpentDead': 256,
#     'totalUnitsHealed': 3,
#     'tripleKills': 0,
#     'trueDamageDealt': 22248,
#     'trueDamageDealtToChampions': 4666,
#     'trueDamageTaken': 322,
#     'turretKills': 0,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionScore': 17,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 2,
#     'wardsPlaced': 11,
#     'win': False},
#    {'assists': 5,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 10175,
#     'champLevel': 13,
#     'championId': 555,
#     'championName': 'Pyke',
#     'championTransform': 0,
#     'consumablesPurchased': 4,
#     'damageDealtToBuildings': 415,
#     'damageDealtToObjectives': 2680,
#     'damageDealtToTurrets': 415,
#     'damageSelfMitigated': 11033,
#     'deaths': 8,
#     'detectorWardsPlaced': 2,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 11096,
#     'goldSpent': 10450,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorsLost': 1,
#     'item0': 3857,
#     'item1': 3117,
#     'item2': 6691,
#     'item3': 3179,
#     'item4': 3142,
#     'item5': 0,
#     'item6': 3340,
#     'itemsPurchased': 20,
#     'killingSprees': 1,
#     'kills': 9,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 5,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 799,
#     'magicDamageDealt': 0,
#     'magicDamageDealtToChampions': 0,
#     'magicDamageTaken': 8225,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 9923, 'var1': 27, 'var2': 75, 'var3': 0},
#         {'perk': 8126, 'var1': 407, 'var2': 0, 'var3': 0},
#         {'perk': 8136, 'var1': 5, 'var2': 10, 'var3': 0},
#         {'perk': 8105, 'var1': 13, 'var2': 5, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8473, 'var1': 667, 'var2': 0, 'var3': 0},
#         {'perk': 8242, 'var1': 59, 'var2': 0, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 23101,
#     'physicalDamageDealtToChampions': 8974,
#     'physicalDamageTaken': 10598,
#     'profileIcon': 4404,
#     'puuid': 'r9_mZslFIqwPMNiko362SeuZS7luHTEXapN_F-hpJv15KjtDipl4Z_b-YD2Mu6FvcI85MswOCXhW7A',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 50,
#     'spell2Casts': 48,
#     'spell3Casts': 30,
#     'spell4Casts': 12,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 7,
#     'summoner2Id': 14,
#     'summonerId': 'wPW6si6_BrV_OC4FTi49Si2PeMbJM-7i2y2NK8tcxORSD1k',
#     'summonerLevel': 306,
#     'summonerName': 'Battlebud',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 22,
#     'timePlayed': 1799,
#     'totalDamageDealt': 33035,
#     'totalDamageDealtToChampions': 11511,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 19103,
#     'totalHeal': 2498,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 33,
#     'totalTimeCCDealt': 115,
#     'totalTimeSpentDead': 248,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 9933,
#     'trueDamageDealtToChampions': 2536,
#     'trueDamageTaken': 279,
#     'turretKills': 0,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionScore': 42,
#     'visionWardsBoughtInGame': 2,
#     'wardsKilled': 4,
#     'wardsPlaced': 30,
#     'win': False},
#    {'assists': 10,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 14485,
#     'champLevel': 15,
#     'championId': 75,
#     'championName': 'Nasus',
#     'championTransform': 0,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 3465,
#     'damageDealtToObjectives': 3465,
#     'damageDealtToTurrets': 3465,
#     'damageSelfMitigated': 36782,
#     'deaths': 7,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 11371,
#     'goldSpent': 11275,
#     'individualPosition': 'TOP',
#     'inhibitorKills': 0,
#     'inhibitorsLost': 0,
#     'item0': 1028,
#     'item1': 6632,
#     'item2': 3047,
#     'item3': 3075,
#     'item4': 3110,
#     'item5': 3082,
#     'item6': 3364,
#     'itemsPurchased': 20,
#     'killingSprees': 1,
#     'kills': 6,
#     'lane': 'TOP',
#     'largestCriticalStrike': 24,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 451,
#     'magicDamageDealt': 9457,
#     'magicDamageDealtToChampions': 4368,
#     'magicDamageTaken': 4394,
#     'neutralMinionsKilled': 4,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 6,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5002, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8360, 'var1': 10, 'var2': 0, 'var3': 0},
#         {'perk': 8304, 'var1': 11, 'var2': 1, 'var3': 5},
#         {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8410, 'var1': 61, 'var2': 0, 'var3': 0}],
#        'style': 8300},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8275, 'var1': 12, 'var2': 0, 'var3': 0},
#         {'perk': 8210, 'var1': 4, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 111997,
#     'physicalDamageDealtToChampions': 11099,
#     'physicalDamageTaken': 24205,
#     'profileIcon': 4573,
#     'puuid': '0HQJ8mCrg5lvbYfx_Vgf_TFimuYKCQeKRKh5bDLYvTbGUgM7y4dj3U5sApKi9y4_r8v5rTJ0KjuEbg',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 181,
#     'spell2Casts': 21,
#     'spell3Casts': 18,
#     'spell4Casts': 6,
#     'summoner1Casts': 6,
#     'summoner1Id': 4,
#     'summoner2Casts': 6,
#     'summoner2Id': 12,
#     'summonerId': 'Z4UT0Q61dwg-wh5vNUuNm3Xh4JwYfPoqPJbEjN5jrk2Qhf0g',
#     'summonerLevel': 208,
#     'summonerName': 'HungryBokChoy',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'TOP',
#     'timeCCingOthers': 14,
#     'timePlayed': 1799,
#     'totalDamageDealt': 123345,
#     'totalDamageDealtToChampions': 15818,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 32431,
#     'totalHeal': 1278,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 170,
#     'totalTimeCCDealt': 184,
#     'totalTimeSpentDead': 228,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 1890,
#     'trueDamageDealtToChampions': 350,
#     'trueDamageTaken': 3830,
#     'turretKills': 1,
#     'turretsLost': 2,
#     'unrealKills': 0,
#     'visionScore': 13,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 3,
#     'wardsPlaced': 4,
#     'win': True},
#    {'assists': 17,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 14233,
#     'champLevel': 15,
#     'championId': 19,
#     'championName': 'Warwick',
#     'championTransform': 0,
#     'consumablesPurchased': 4,
#     'damageDealtToBuildings': 254,
#     'damageDealtToObjectives': 16410,
#     'damageDealtToTurrets': 254,
#     'damageSelfMitigated': 34377,
#     'deaths': 7,
#     'detectorWardsPlaced': 3,
#     'doubleKills': 0,
#     'dragonKills': 1,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 11050,
#     'goldSpent': 10925,
#     'individualPosition': 'JUNGLE',
#     'inhibitorKills': 0,
#     'inhibitorsLost': 0,
#     'item0': 3075,
#     'item1': 3748,
#     'item2': 3068,
#     'item3': 0,
#     'item4': 0,
#     'item5': 3047,
#     'item6': 3364,
#     'itemsPurchased': 24,
#     'killingSprees': 0,
#     'kills': 3,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 2,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 461,
#     'magicDamageDealt': 63458,
#     'magicDamageDealtToChampions': 10710,
#     'magicDamageTaken': 5805,
#     'neutralMinionsKilled': 152,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 7,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8005, 'var1': 1594, 'var2': 847, 'var3': 747},
#         {'perk': 9111, 'var1': 1291, 'var2': 400, 'var3': 0},
#         {'perk': 9104, 'var1': 13, 'var2': 10, 'var3': 0},
#         {'perk': 8299, 'var1': 662, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8232, 'var1': 5, 'var2': 50, 'var3': 0},
#         {'perk': 8275, 'var1': 21, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 67836,
#     'physicalDamageDealtToChampions': 4786,
#     'physicalDamageTaken': 28457,
#     'profileIcon': 3165,
#     'puuid': '-bj1j_k29eF1uHNweX5xidFXmXU9i8d5pXLoDeMhFMPcn1Qyp6mH5bBW20z_T4R_-bXc9yfDWNwF1Q',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 99,
#     'spell2Casts': 7,
#     'spell3Casts': 35,
#     'spell4Casts': 9,
#     'summoner1Casts': 17,
#     'summoner1Id': 11,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': 'AdzoZysw8xjXPhM6TogVGsQEuQqi3PmRIShAUbzBiG0jPvPp',
#     'summonerLevel': 41,
#     'summonerName': 'Adamation Cancel',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'JUNGLE',
#     'timeCCingOthers': 22,
#     'timePlayed': 1799,
#     'totalDamageDealt': 143723,
#     'totalDamageDealtToChampions': 16394,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 35546,
#     'totalHeal': 17238,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 9,
#     'totalTimeCCDealt': 215,
#     'totalTimeSpentDead': 212,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 12429,
#     'trueDamageDealtToChampions': 897,
#     'trueDamageTaken': 1283,
#     'turretKills': 1,
#     'turretsLost': 2,
#     'unrealKills': 0,
#     'visionScore': 28,
#     'visionWardsBoughtInGame': 3,
#     'wardsKilled': 6,
#     'wardsPlaced': 4,
#     'win': True},
#    {'assists': 7,
#     'baronKills': 0,
#     'bountyLevel': 4,
#     'champExperience': 16223,
#     'champLevel': 16,
#     'championId': 58,
#     'championName': 'Renekton',
#     'championTransform': 0,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 5213,
#     'damageDealtToObjectives': 5871,
#     'damageDealtToTurrets': 5213,
#     'damageSelfMitigated': 21762,
#     'deaths': 4,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 13325,
#     'goldSpent': 11950,
#     'individualPosition': 'MIDDLE',
#     'inhibitorKills': 0,
#     'inhibitorsLost': 0,
#     'item0': 6333,
#     'item1': 6631,
#     'item2': 3047,
#     'item3': 3053,
#     'item4': 3076,
#     'item5': 0,
#     'item6': 3340,
#     'itemsPurchased': 19,
#     'killingSprees': 3,
#     'kills': 11,
#     'lane': 'MIDDLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 569,
#     'magicDamageDealt': 2914,
#     'magicDamageDealtToChampions': 1989,
#     'magicDamageTaken': 7836,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 8,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8005, 'var1': 2751, 'var2': 1643, 'var3': 1107},
#         {'perk': 9111, 'var1': 1652, 'var2': 360, 'var3': 0},
#         {'perk': 9104, 'var1': 18, 'var2': 50, 'var3': 0},
#         {'perk': 8299, 'var1': 603, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8446, 'var1': 2190, 'var2': 0, 'var3': 0},
#         {'perk': 8473, 'var1': 924, 'var2': 0, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 102382,
#     'physicalDamageDealtToChampions': 19509,
#     'physicalDamageTaken': 13340,
#     'profileIcon': 1629,
#     'puuid': 'qivIPQ8d-QzvDUYW5PLaVzHwuz8WOu9reCkC6mbAxwfdycw5htjTLi-ll2i3yK3mX0PhB86f1o8K8Q',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 53,
#     'spell2Casts': 27,
#     'spell3Casts': 42,
#     'spell4Casts': 6,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 5,
#     'summoner2Id': 14,
#     'summonerId': '4uANPs5GuNcCML_y-0y8C855yWS43dFnIVoLdXlAGBCGpZw',
#     'summonerLevel': 194,
#     'summonerName': 'cultist player',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'MIDDLE',
#     'timeCCingOthers': 29,
#     'timePlayed': 1799,
#     'totalDamageDealt': 106284,
#     'totalDamageDealtToChampions': 22487,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 23546,
#     'totalHeal': 7503,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 166,
#     'totalTimeCCDealt': 35,
#     'totalTimeSpentDead': 114,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 988,
#     'trueDamageDealtToChampions': 988,
#     'trueDamageTaken': 2369,
#     'turretKills': 1,
#     'turretsLost': 2,
#     'unrealKills': 0,
#     'visionScore': 20,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 5,
#     'wardsPlaced': 9,
#     'win': True},
#    {'assists': 4,
#     'baronKills': 0,
#     'bountyLevel': 1,
#     'champExperience': 12933,
#     'champLevel': 14,
#     'championId': 360,
#     'championName': 'Samira',
#     'championTransform': 0,
#     'consumablesPurchased': 1,
#     'damageDealtToBuildings': 4202,
#     'damageDealtToObjectives': 9208,
#     'damageDealtToTurrets': 4202,
#     'damageSelfMitigated': 12870,
#     'deaths': 6,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 11784,
#     'goldSpent': 10950,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorsLost': 0,
#     'item0': 1018,
#     'item1': 1038,
#     'item2': 3047,
#     'item3': 6673,
#     'item4': 6676,
#     'item5': 1053,
#     'item6': 3363,
#     'itemsPurchased': 20,
#     'killingSprees': 2,
#     'kills': 9,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 470,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 3,
#     'longestTimeSpentLiving': 414,
#     'magicDamageDealt': 13249,
#     'magicDamageDealtToChampions': 1637,
#     'magicDamageTaken': 1710,
#     'neutralMinionsKilled': 16,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 47, 'var2': 0, 'var3': 0},
#         {'perk': 8009, 'var1': 1124, 'var2': 0, 'var3': 0},
#         {'perk': 9103, 'var1': 21, 'var2': 50, 'var3': 0},
#         {'perk': 8014, 'var1': 255, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8139, 'var1': 742, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 1301, 'var2': 5, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 101088,
#     'physicalDamageDealtToChampions': 9255,
#     'physicalDamageTaken': 14487,
#     'profileIcon': 4928,
#     'puuid': 'rqijjUkx4AhCc5PAaUGobs0B-VzySsLh8p5Wq9sWZY5pvD7oIkoOZDWXq-B0zFDCQ-QUEXmpU19BaQ',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 105,
#     'spell2Casts': 18,
#     'spell3Casts': 23,
#     'spell4Casts': 3,
#     'summoner1Casts': 4,
#     'summoner1Id': 4,
#     'summoner2Casts': 3,
#     'summoner2Id': 7,
#     'summonerId': 'j1lKAutQBVb8mgDLDWYIQHVzWjJhiWYhN1-gVl9GDcwxSdw',
#     'summonerLevel': 239,
#     'summonerName': 'Horny Chan',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 0,
#     'timePlayed': 1799,
#     'totalDamageDealt': 114595,
#     'totalDamageDealtToChampions': 11150,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 18598,
#     'totalHeal': 2870,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 174,
#     'totalTimeCCDealt': 2,
#     'totalTimeSpentDead': 188,
#     'totalUnitsHealed': 1,
#     'tripleKills': 1,
#     'trueDamageDealt': 257,
#     'trueDamageDealtToChampions': 257,
#     'trueDamageTaken': 2401,
#     'turretKills': 2,
#     'turretsLost': 2,
#     'unrealKills': 0,
#     'visionScore': 13,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 2,
#     'wardsPlaced': 8,
#     'win': True},
#    {'assists': 11,
#     'baronKills': 0,
#     'bountyLevel': 4,
#     'champExperience': 11246,
#     'champLevel': 13,
#     'championId': 63,
#     'championName': 'Brand',
#     'championTransform': 0,
#     'consumablesPurchased': 6,
#     'damageDealtToBuildings': 1403,
#     'damageDealtToObjectives': 7277,
#     'damageDealtToTurrets': 1403,
#     'damageSelfMitigated': 4990,
#     'deaths': 3,
#     'detectorWardsPlaced': 4,
#     'doubleKills': 0,
#     'dragonKills': 1,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 10458,
#     'goldSpent': 9450,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 1,
#     'inhibitorsLost': 0,
#     'item0': 3853,
#     'item1': 3020,
#     'item2': 6653,
#     'item3': 4637,
#     'item4': 1082,
#     'item5': 3916,
#     'item6': 3364,
#     'itemsPurchased': 22,
#     'killingSprees': 2,
#     'kills': 7,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 606,
#     'magicDamageDealt': 73287,
#     'magicDamageDealtToChampions': 22827,
#     'magicDamageTaken': 2139,
#     'neutralMinionsKilled': 18,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 1316, 'var2': 17, 'var3': 0},
#         {'perk': 8139, 'var1': 836, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 1468, 'var2': 5, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8226, 'var1': 250, 'var2': 561, 'var3': 0},
#         {'perk': 8237, 'var1': 497, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 4802,
#     'physicalDamageDealtToChampions': 557,
#     'physicalDamageTaken': 9451,
#     'profileIcon': 4571,
#     'puuid': 'v_cqw8qSe6DNaydGhtGkRmEnNUH_EnQmEuRQbg_E2cTgSne_0TDaU9xKZFk9m-1utO7ip2P1o_Kd5w',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 79,
#     'spell2Casts': 81,
#     'spell3Casts': 71,
#     'spell4Casts': 13,
#     'summoner1Casts': 4,
#     'summoner1Id': 4,
#     'summoner2Casts': 4,
#     'summoner2Id': 3,
#     'summonerId': 'HXcRJa4gJqrb4zHeFlAEbAFKbOxFn_Idb8NjdRfttEfP4SA',
#     'summonerLevel': 481,
#     'summonerName': 'Zarude',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 13,
#     'timePlayed': 1799,
#     'totalDamageDealt': 83301,
#     'totalDamageDealtToChampions': 23496,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 12991,
#     'totalHeal': 2326,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 44,
#     'totalTimeCCDealt': 50,
#     'totalTimeSpentDead': 66,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 5211,
#     'trueDamageDealtToChampions': 112,
#     'trueDamageTaken': 1400,
#     'turretKills': 0,
#     'turretsLost': 2,
#     'unrealKills': 0,
#     'visionScore': 62,
#     'visionWardsBoughtInGame': 4,
#     'wardsKilled': 5,
#     'wardsPlaced': 27,
#     'win': True}],
#   'platformId': 'NA1',
#   'queueId': 420,
#   'teams': [{'bans': [{'championId': 517, 'pickTurn': 1},
#      {'championId': 35, 'pickTurn': 2},
#      {'championId': 6, 'pickTurn': 3},
#      {'championId': 64, 'pickTurn': 4},
#      {'championId': 84, 'pickTurn': 5}],
#     'objectives': {'baron': {'first': True, 'kills': 1},
#      'champion': {'first': True, 'kills': 27},
#      'dragon': {'first': True, 'kills': 2},
#      'inhibitor': {'first': False, 'kills': 0},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': True, 'kills': 2}},
#     'teamId': 100,
#     'win': False},
#    {'bans': [{'championId': 62, 'pickTurn': 6},
#      {'championId': 25, 'pickTurn': 7},
#      {'championId': 35, 'pickTurn': 8},
#      {'championId': 238, 'pickTurn': 9},
#      {'championId': 157, 'pickTurn': 10}],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': False, 'kills': 37},
#      'dragon': {'first': False, 'kills': 2},
#      'inhibitor': {'first': True, 'kills': 1},
#      'riftHerald': {'first': True, 'kills': 1},
#      'tower': {'first': False, 'kills': 5}},
#     'teamId': 200,
#     'win': True}]}}
