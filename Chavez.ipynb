# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from sklearn.model_selection import train_test_split
import re
from acquire import extract
from prepare import prepare

# %%
timeline_data = pd.read_json('timeline_data_user_Xmithie_end_40.json')
other_game_data = pd.read_json('other_game_data_user_Xmithie_end_40.json')
timeline_data = timeline_data.to_dict(orient = 'records')
other_game_data = other_game_data.to_dict(orient = 'records')

# %%
df = extract(timeline_data, other_game_data, 15)
# Out:
# Skipping: 0 due to <15 min or not classic
# Finished with: 1 of 9
# Finished with: 2 of 9
# Skipping: 3 due to <15 min or not classic
# Skipping: 4 due to <15 min or not classic
# Finished with: 5 of 9
# Skipping: 6 due to <15 min or not classic
# Skipping: 7 due to <15 min or not classic
# Skipping: 8 due to <15 min or not classic
# Skipping: 9 due to <15 min or not classic

# %%
train, test = prepare(df)

# %%
train.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 1 to 2
# Data columns (total 223 columns):
#  #    Column                                 Dtype
# ---   ------                                 -----
#  0    airdragon_team100                      float64
#  1    assistsplayer_1                        float64
#  2    assistsplayer_10                       float64
#  3    assistsplayer_2                        float64
#  4    assistsplayer_3                        float64
#  5    assistsplayer_4                        float64
#  6    assistsplayer_5                        float64
#  7    assistsplayer_6                        float64
#  8    assistsplayer_7                        float64
#  9    assistsplayer_8                        float64
#  10   assistsplayer_9                        float64
#  11   baron_team100                          float64
#  12   chemtechdragon_team100                 float64
#  13   currentGold_1                          float64
#  14   currentGold_10                         float64
#  15   currentGold_2                          float64
#  16   currentGold_3                          float64
#  17   currentGold_4                          float64
#  18   currentGold_5                          float64
#  19   currentGold_6                          float64
#  20   currentGold_7                          float64
#  21   currentGold_8                          float64
#  22   currentGold_9                          float64
#  23   deathsplayer_1                         float64
#  24   deathsplayer_10                        float64
#  25   deathsplayer_2                         float64
#  26   deathsplayer_3                         float64
#  27   deathsplayer_4                         float64
#  28   deathsplayer_5                         float64
#  29   deathsplayer_6                         float64
#  30   deathsplayer_7                         float64
#  31   deathsplayer_8                         float64
#  32   deathsplayer_9                         float64
#  33   dragon_team100                         float64
#  34   dragon_team200                         float64
#  35   earthdragon_team100                    float64
#  36   earthdragon_team200                    float64
#  37   firedragon_team100                     float64
#  38   firedragon_team200                     float64
#  39   gameDuration                           object
#  40   gameEndTimestamp                       object
#  41   gameId                                 object
#  42   gameMode                               object
#  43   gameName                               object
#  44   gameStartTimestamp                     object
#  45   gameType                               object
#  46   gameVersion                            object
#  47   goldPerSecond_1                        float64
#  48   goldPerSecond_10                       float64
#  49   goldPerSecond_2                        float64
#  50   goldPerSecond_3                        float64
#  51   goldPerSecond_4                        float64
#  52   goldPerSecond_5                        float64
#  53   goldPerSecond_6                        float64
#  54   goldPerSecond_7                        float64
#  55   goldPerSecond_8                        float64
#  56   goldPerSecond_9                        float64
#  57   hextechdragon_team200                  float64
#  58   inhibs_lost_team200                    float64
#  59   jungleMinionsKilled_1                  float64
#  60   jungleMinionsKilled_10                 float64
#  61   jungleMinionsKilled_2                  float64
#  62   jungleMinionsKilled_3                  float64
#  63   jungleMinionsKilled_4                  float64
#  64   jungleMinionsKilled_5                  float64
#  65   jungleMinionsKilled_6                  float64
#  66   jungleMinionsKilled_7                  float64
#  67   jungleMinionsKilled_8                  float64
#  68   jungleMinionsKilled_9                  float64
#  69   killsplayer_1                          float64
#  70   killsplayer_10                         float64
#  71   killsplayer_2                          float64
#  72   killsplayer_3                          float64
#  73   killsplayer_4                          float64
#  74   killsplayer_5                          float64
#  75   killsplayer_6                          float64
#  76   killsplayer_7                          float64
#  77   killsplayer_8                          float64
#  78   killsplayer_9                          float64
#  79   level_1                                float64
#  80   level_10                               float64
#  81   level_2                                float64
#  82   level_3                                float64
#  83   level_4                                float64
#  84   level_5                                float64
#  85   level_6                                float64
#  86   level_7                                float64
#  87   level_8                                float64
#  88   level_9                                float64
#  89   magicDamageDoneToChampions_1           float64
#  90   magicDamageDoneToChampions_10          float64
#  91   magicDamageDoneToChampions_2           float64
#  92   magicDamageDoneToChampions_3           float64
#  93   magicDamageDoneToChampions_4           float64
#  94   magicDamageDoneToChampions_5           float64
#  95   magicDamageDoneToChampions_6           float64
#  96   magicDamageDoneToChampions_7           float64
#  97   magicDamageDoneToChampions_8           float64
#  98   magicDamageDoneToChampions_9           float64
#  99   matchId                                object
#  100  minionsKilled_1                        float64
#  101  minionsKilled_10                       float64
#  102  minionsKilled_2                        float64
#  103  minionsKilled_3                        float64
#  104  minionsKilled_4                        float64
#  105  minionsKilled_5                        float64
#  106  minionsKilled_6                        float64
#  107  minionsKilled_7                        float64
#  108  minionsKilled_8                        float64
#  109  minionsKilled_9                        float64
#  110  physicalDamageDoneToChampions_1        float64
#  111  physicalDamageDoneToChampions_10       float64
#  112  physicalDamageDoneToChampions_2        float64
#  113  physicalDamageDoneToChampions_3        float64
#  114  physicalDamageDoneToChampions_4        float64
#  115  physicalDamageDoneToChampions_5        float64
#  116  physicalDamageDoneToChampions_6        float64
#  117  physicalDamageDoneToChampions_7        float64
#  118  physicalDamageDoneToChampions_8        float64
#  119  physicalDamageDoneToChampions_9        float64
#  120  queueId                                object
#  121  riftherald_team100                     float64
#  122  riftherald_team300                     float64
#  123  timeEnemySpentControlled_1             float64
#  124  timeEnemySpentControlled_10            float64
#  125  timeEnemySpentControlled_2             float64
#  126  timeEnemySpentControlled_3             float64
#  127  timeEnemySpentControlled_4             float64
#  128  timeEnemySpentControlled_5             float64
#  129  timeEnemySpentControlled_6             float64
#  130  timeEnemySpentControlled_7             float64
#  131  timeEnemySpentControlled_8             float64
#  132  timeEnemySpentControlled_9             float64
#  133  timestamp                              float64
#  134  totalDamageDoneToChampions_1           float64
#  135  totalDamageDoneToChampions_10          float64
#  136  totalDamageDoneToChampions_2           float64
#  137  totalDamageDoneToChampions_3           float64
#  138  totalDamageDoneToChampions_4           float64
#  139  totalDamageDoneToChampions_5           float64
#  140  totalDamageDoneToChampions_6           float64
#  141  totalDamageDoneToChampions_7           float64
#  142  totalDamageDoneToChampions_8           float64
#  143  totalDamageDoneToChampions_9           float64
#  144  totalGold_1                            float64
#  145  totalGold_10                           float64
#  146  totalGold_2                            float64
#  147  totalGold_3                            float64
#  148  totalGold_4                            float64
#  149  totalGold_5                            float64
#  150  totalGold_6                            float64
#  151  totalGold_7                            float64
#  152  totalGold_8                            float64
#  153  totalGold_9                            float64
#  154  towers_lost_team100                    float64
#  155  towers_lost_team200                    float64
#  156  trueDamageDoneToChampions_1            float64
#  157  trueDamageDoneToChampions_10           float64
#  158  trueDamageDoneToChampions_2            float64
#  159  trueDamageDoneToChampions_3            float64
#  160  trueDamageDoneToChampions_4            float64
#  161  trueDamageDoneToChampions_5            float64
#  162  trueDamageDoneToChampions_6            float64
#  163  trueDamageDoneToChampions_7            float64
#  164  trueDamageDoneToChampions_8            float64
#  165  trueDamageDoneToChampions_9            float64
#  166  ward_player_0                          float64
#  167  ward_player_1                          float64
#  168  ward_player_10                         float64
#  169  ward_player_2                          float64
#  170  ward_player_3                          float64
#  171  ward_player_4                          float64
#  172  ward_player_5                          float64
#  173  ward_player_6                          float64
#  174  ward_player_7                          float64
#  175  ward_player_8                          float64
#  176  ward_player_9                          float64
#  177  waterdragon_team100                    float64
#  178  winningTeam                            float64
#  179  xp_1                                   float64
#  180  xp_10                                  float64
#  181  xp_2                                   float64
#  182  xp_3                                   float64
#  183  xp_4                                   float64
#  184  xp_5                                   float64
#  185  xp_6                                   float64
#  186  xp_7                                   float64
#  187  xp_8                                   float64
#  188  xp_9                                   float64
#  189  BlueTeamDeaths                         int64
#  190  RedTeamDeaths                          int64
#  191  BlueTeamGoldPerSec                     int64
#  192  RedTeamGoldPerSec                      int64
#  193  BlueTeamJungleMinionsKilled            int64
#  194  RedTeamJungleMinionsKilled             int64
#  195  BlueTeamKills                          int64
#  196  RedTeamKills                           int64
#  197  BlueTeamLevel                          int64
#  198  RedTeamLevel                           int64
#  199  BlueTeamMagicDamageDoneToChampions     int64
#  200  RedTeamMagicDamageDoneToChampions      int64
#  201  BlueTeamMinionsKilled                  int64
#  202  RedTeamMinionsKilled                   int64
#  203  BlueTeamPhysicalDamageDoneToChampions  int64
#  204  RedTeamPhysicalDamageDoneToChampions   int64
#  205  BlueTeamTimeEnemySpentControlled       int64
#  206  RedTeamTimeEnemySpentControlled        int64
#  207  BlueTeamTotalDamageDoneToChampions     int64
#  208  RedTeamTotalDamageDoneToChampions      int64
#  209  BlueTeamTotalGold                      int64
#  210  RedTeamTotalGold                       int64
#  211  BlueTeamTrueDamageDoneToChampions      int64
#  212  RedTeamTrueDamageDoneToChampions       int64
#  213  BlueTeamWards                          int64
#  214  RedTeamWards                           int64
#  215  BlueTeamAssists                        int64
#  216  RedTeamAssists                         int64
#  217  BlueTeamXp                             int64
#  218  RedTeamXp                              int64
#  219  BlueTeamTotalGoldDifference            int64
#  220  RedTeamTotalGoldDifference             int64
#  221  BlueTeamMVPKills                       float64
#  222  RedTeamMVPKills                        float64
# dtypes: float64(181), int64(32), object(10)
# memory usage: 3.5+ KB

# %%
columns = ['assistsplayer_10', 'assistsplayer_2', 'assistsplayer_3', 'assistsplayer_4', 'assistsplayer_5', 'assistsplayer_8', 'assistsplayer_9', 'assistsplayer_1' 'currentGold_1', 'currentGold_10', 'currentGold_2', 'currentGold_3', 'currentGold_4', 'currentGold_5', 'currentGold_6', 'currentGold_7', 'currentGold_8', 'currentGold_9', 'deathsplayer_1', 'deathsplayer_10', 'deathsplayer_2', 'deathsplayer_3', 'deathsplayer_4', 'deathsplayer_5', 'deathsplayer_6', 'deathsplayer_7', 'deathsplayer_8', 'deathsplayer_9', 'dragon_team100', 'dragon_team200', 'firedragon_team100', 'firedragon_team200', 'gameDuration', 'gameEndTimestamp', 'gameId', 'gameMode', 'gameName', 'gameStartTimestamp', 'gameType', 'gameVersion', 'goldPerSecond_1', 'goldPerSecond_10', 'goldPerSecond_2', 'goldPerSecond_3', 'goldPerSecond_4', 'goldPerSecond_5', 'goldPerSecond_6', 'goldPerSecond_7', 'goldPerSecond_8', 'goldPerSecond_9', 'hextechdragon_team200', 'inhibs_lost_team200', 'jungleMinionsKilled_1', 'jungleMinionsKilled_10', 'jungleMinionsKilled_2', 'jungleMinionsKilled_3', 'jungleMinionsKilled_4', 'jungleMinionsKilled_5', 'jungleMinionsKilled_6', 'jungleMinionsKilled_7', 'jungleMinionsKilled_8', 'jungleMinionsKilled_9', 'killsplayer_1', 'killsplayer_2', 'killsplayer_3', 'killsplayer_4', 'killsplayer_5', 'killsplayer_6', 'killsplayer_7', 'killsplayer_8', 'killsplayer_9', 'killsplayer_10', 'level_1', 'level_10', 'level_2', 'level_3', 'level_4', 'level_5', 'level_6', 'level_7', 'level_8', 'level_9', 'magicDamageDoneToChampions_1', 'magicDamageDoneToChampions_10', 'magicDamageDoneToChampions_2', 'magicDamageDoneToChampions_3', 'magicDamageDoneToChampions_4', 'magicDamageDoneToChampions_5', 'magicDamageDoneToChampions_6', 'magicDamageDoneToChampions_7', 'magicDamageDoneToChampions_8', 'magicDamageDoneToChampions_9', 'matchId', 'minionsKilled_1', 'minionsKilled_10', 'minionsKilled_2', 'minionsKilled_3', 'minionsKilled_4', 'minionsKilled_5', 'minionsKilled_6', 'minionsKilled_7', 'minionsKilled_8', 'minionsKilled_9', 'physicalDamageDoneToChampions_1', 'physicalDamageDoneToChampions_10', 'physicalDamageDoneToChampions_2', 'physicalDamageDoneToChampions_3', 'physicalDamageDoneToChampions_4', 'physicalDamageDoneToChampions_5', 'physicalDamageDoneToChampions_6', 'physicalDamageDoneToChampions_7', 'physicalDamageDoneToChampions_8', 'physicalDamageDoneToChampions_9', 'queueId', 'riftherald_team100', 'timeEnemySpentControlled_1', 'timeEnemySpentControlled_10', 'timeEnemySpentControlled_2', 'timeEnemySpentControlled_3', 'timeEnemySpentControlled_4', 'timeEnemySpentControlled_5', 'timeEnemySpentControlled_6', 'timeEnemySpentControlled_7', 'timeEnemySpentControlled_8', 'timeEnemySpentControlled_9', 'timestamp', 'totalDamageDoneToChampions_1', 'totalDamageDoneToChampions_10', 'totalDamageDoneToChampions_2', 'totalDamageDoneToChampions_3', 'totalDamageDoneToChampions_4', 'totalDamageDoneToChampions_5', 'totalDamageDoneToChampions_6', 'totalDamageDoneToChampions_7', 'totalDamageDoneToChampions_8', 'totalDamageDoneToChampions_9', 'totalGold_1', 'totalGold_10', 'totalGold_2', 'totalGold_3', 'totalGold_4', 'totalGold_5', 'totalGold_6', 'totalGold_7', 'totalGold_8', 'totalGold_9', 'towers_lost_team100', 'towers_lost_team200', 'trueDamageDoneToChampions_1', 'trueDamageDoneToChampions_10', 'trueDamageDoneToChampions_2', 'trueDamageDoneToChampions_3', 'trueDamageDoneToChampions_4', 'trueDamageDoneToChampions_5', 'trueDamageDoneToChampions_6', 'trueDamageDoneToChampions_7', 'trueDamageDoneToChampions_8', 'trueDamageDoneToChampions_9', 'ward_player_1', 'ward_player_10', 'ward_player_2', 'ward_player_3', 'ward_player_4', 'ward_player_5', 'ward_player_6', 'ward_player_7', 'ward_player_8', 'ward_player_9', 'waterdragon_team100', 'winningTeam', 'xp_1', 'xp_10', 'xp_2', 'xp_3', 'xp_4', 'xp_5', 'xp_6', 'xp_7', 'xp_8', 'xp_9', 'airdragon_team100', 'assistsplayer_7', 'chemtechdragon_team100', 'earthdragon_team100', 'killsplayer_10', 'killsplayer_6', 'killsplayer_8', 'riftherald_team300', 'assistsplayer_1', 'baron_team100', 'earthdragon_team200', 'ward_player_0']

# %%
df = pd.DataFrame(columns=columns)

# %%
list(df.columns)
# Out:
# ['assistsplayer_10',
#  'assistsplayer_2',
#  'assistsplayer_3',
#  'assistsplayer_4',
#  'assistsplayer_5',
#  'assistsplayer_8',
#  'assistsplayer_9',
#  'currentGold_1',
#  'currentGold_10',
#  'currentGold_2',
#  'currentGold_3',
#  'currentGold_4',
#  'currentGold_5',
#  'currentGold_6',
#  'currentGold_7',
#  'currentGold_8',
#  'currentGold_9',
#  'deathsplayer_1',
#  'deathsplayer_10',
#  'deathsplayer_2',
#  'deathsplayer_3',
#  'deathsplayer_4',
#  'deathsplayer_5',
#  'deathsplayer_6',
#  'deathsplayer_7',
#  'deathsplayer_8',
#  'deathsplayer_9',
#  'dragon_team100',
#  'dragon_team200',
#  'firedragon_team100',
#  'firedragon_team200',
#  'gameDuration',
#  'gameEndTimestamp',
#  'gameId',
#  'gameMode',
#  'gameName',
#  'gameStartTimestamp',
#  'gameType',
#  'gameVersion',
#  'goldPerSecond_1',
#  'goldPerSecond_10',
#  'goldPerSecond_2',
#  'goldPerSecond_3',
#  'goldPerSecond_4',
#  'goldPerSecond_5',
#  'goldPerSecond_6',
#  'goldPerSecond_7',
#  'goldPerSecond_8',
#  'goldPerSecond_9',
#  'hextechdragon_team200',
#  'inhibs_lost_team200',
#  'jungleMinionsKilled_1',
#  'jungleMinionsKilled_10',
#  'jungleMinionsKilled_2',
#  'jungleMinionsKilled_3',
#  'jungleMinionsKilled_4',
#  'jungleMinionsKilled_5',
#  'jungleMinionsKilled_6',
#  'jungleMinionsKilled_7',
#  'jungleMinionsKilled_8',
#  'jungleMinionsKilled_9',
#  'killsplayer_1',
#  'killsplayer_2',
#  'killsplayer_3',
#  'killsplayer_4',
#  'killsplayer_5',
#  'killsplayer_7',
#  'killsplayer_9',
#  'level_1',
#  'level_10',
#  'level_2',
#  'level_3',
#  'level_4',
#  'level_5',
#  'level_6',
#  'level_7',
#  'level_8',
#  'level_9',
#  'magicDamageDoneToChampions_1',
#  'magicDamageDoneToChampions_10',
#  'magicDamageDoneToChampions_2',
#  'magicDamageDoneToChampions_3',
#  'magicDamageDoneToChampions_4',
#  'magicDamageDoneToChampions_5',
#  'magicDamageDoneToChampions_6',
#  'magicDamageDoneToChampions_7',
#  'magicDamageDoneToChampions_8',
#  'magicDamageDoneToChampions_9',
#  'matchId',
#  'minionsKilled_1',
#  'minionsKilled_10',
#  'minionsKilled_2',
#  'minionsKilled_3',
#  'minionsKilled_4',
#  'minionsKilled_5',
#  'minionsKilled_6',
#  'minionsKilled_7',
#  'minionsKilled_8',
#  'minionsKilled_9',
#  'physicalDamageDoneToChampions_1',
#  'physicalDamageDoneToChampions_10',
#  'physicalDamageDoneToChampions_2',
#  'physicalDamageDoneToChampions_3',
#  'physicalDamageDoneToChampions_4',
#  'physicalDamageDoneToChampions_5',
#  'physicalDamageDoneToChampions_6',
#  'physicalDamageDoneToChampions_7',
#  'physicalDamageDoneToChampions_8',
#  'physicalDamageDoneToChampions_9',
#  'queueId',
#  'riftherald_team100',
#  'timeEnemySpentControlled_1',
#  'timeEnemySpentControlled_10',
#  'timeEnemySpentControlled_2',
#  'timeEnemySpentControlled_3',
#  'timeEnemySpentControlled_4',
#  'timeEnemySpentControlled_5',
#  'timeEnemySpentControlled_6',
#  'timeEnemySpentControlled_7',
#  'timeEnemySpentControlled_8',
#  'timeEnemySpentControlled_9',
#  'timestamp',
#  'totalDamageDoneToChampions_1',
#  'totalDamageDoneToChampions_10',
#  'totalDamageDoneToChampions_2',
#  'totalDamageDoneToChampions_3',
#  'totalDamageDoneToChampions_4',
#  'totalDamageDoneToChampions_5',
#  'totalDamageDoneToChampions_6',
#  'totalDamageDoneToChampions_7',
#  'totalDamageDoneToChampions_8',
#  'totalDamageDoneToChampions_9',
#  'totalGold_1',
#  'totalGold_10',
#  'totalGold_2',
#  'totalGold_3',
#  'totalGold_4',
#  'totalGold_5',
#  'totalGold_6',
#  'totalGold_7',
#  'totalGold_8',
#  'totalGold_9',
#  'towers_lost_team100',
#  'towers_lost_team200',
#  'trueDamageDoneToChampions_1',
#  'trueDamageDoneToChampions_10',
#  'trueDamageDoneToChampions_2',
#  'trueDamageDoneToChampions_3',
#  'trueDamageDoneToChampions_4',
#  'trueDamageDoneToChampions_5',
#  'trueDamageDoneToChampions_6',
#  'trueDamageDoneToChampions_7',
#  'trueDamageDoneToChampions_8',
#  'trueDamageDoneToChampions_9',
#  'ward_player_1',
#  'ward_player_10',
#  'ward_player_2',
#  'ward_player_3',
#  'ward_player_4',
#  'ward_player_5',
#  'ward_player_6',
#  'ward_player_7',
#  'ward_player_8',
#  'ward_player_9',
#  'waterdragon_team100',
#  'winningTeam',
#  'xp_1',
#  'xp_10',
#  'xp_2',
#  'xp_3',
#  'xp_4',
#  'xp_5',
#  'xp_6',
#  'xp_7',
#  'xp_8',
#  'xp_9',
#  'airdragon_team100',
#  'assistsplayer_7',
#  'chemtechdragon_team100',
#  'earthdragon_team100',
#  'killsplayer_10',
#  'killsplayer_6',
#  'killsplayer_8',
#  'riftherald_team300',
#  'assistsplayer_1',
#  'baron_team100',
#  'earthdragon_team200',
#  'ward_player_0']

# %%
def clean(df):
    
    df = df.fillna(0)
    columns=['deathsplayer_',
                'goldPerSecond_',
                'jungleMinionsKilled_',
                'killsplayer_',
                'level_',
                'magicDamageDoneToChampions_',
                'minionsKilled_',
                'physicalDamageDoneToChampions_',
                'timeEnemySpentControlled_',
                'totalDamageDoneToChampions_',
                'totalGold_',
                'trueDamageDoneToChampions_',
                'ward_player_',
                'assistsplayer_',
                'xp_']

    for col in columns:
        df[f'team_{col}100'] = 0
        df[f'team_{col}200'] = 0

    for index, value in enumerate(df.iterrows()):
        for col in columns:
            
            total = 0
            
            for i in range(1, 6):
                total += int(df.iloc[index][f'{col}{i}'])
            
            df.at[index, f'team_{col}100'] = total
        
            total = 0
            
            for i in range(6, 11):
                total += int(df.iloc[index][f'{col}{i}'])
            
            df.at[index, f'team_{col}200'] = total
    
    return df

# %%
df = clean(df)

# %%
d = {}

# %%
d= {'assistsplayer_10':0,
'assistsplayer_2':0,
'assistsplayer_3':0,
'assistsplayer_4':0,
'assistsplayer_5':0,
'assistsplayer_8':0,
'assistsplayer_9':0,
'assistsplayer_1':0,
'assistsplayer_6':0,'assistsplayer_7':0,
'currentGold_1':0,
'currentGold_10':0,
'currentGold_2':0,
'currentGold_3':0,
'currentGold_4':0,
'currentGold_5':0,
'currentGold_6':0,
'currentGold_7':0,
'currentGold_8':0,
'currentGold_9':0,
'deathsplayer_1':0,
'deathsplayer_10':0,
'deathsplayer_2':0,
'deathsplayer_3':0,
'deathsplayer_4':0,
'deathsplayer_5':0,
'deathsplayer_6':0,
'deathsplayer_7':0,
'deathsplayer_8':0,
'deathsplayer_9':0,
'dragon_team100':0,
'dragon_team200':0,
'firedragon_team100':0,
'firedragon_team200':0,
'gameDuration':0,
'gameEndTimestamp':0,
'gameId':0,
'gameMode':0,
'gameName':0,
'gameStartTimestamp':0,
'gameType':0,
'gameVersion':0,
'goldPerSecond_1':0,
'goldPerSecond_10':0,
'goldPerSecond_2':0,
'goldPerSecond_3':0,
'goldPerSecond_4':0,
'goldPerSecond_5':0,
'goldPerSecond_6':0,
'goldPerSecond_7':0,
'goldPerSecond_8':0,
'goldPerSecond_9':0,
'hextechdragon_team200':0,
'inhibs_lost_team200':0,
'jungleMinionsKilled_1':0,
'jungleMinionsKilled_10':0,
'jungleMinionsKilled_2':0,
'jungleMinionsKilled_3':0,
'jungleMinionsKilled_4':0,
'jungleMinionsKilled_5':0,
'jungleMinionsKilled_6':0,
'jungleMinionsKilled_7':0,
'jungleMinionsKilled_8':0,
'jungleMinionsKilled_9':0,
'killsplayer_1':0,
'killsplayer_2':0,
'killsplayer_3':0,
'killsplayer_4':0,
'killsplayer_5':0,
'killsplayer_6':0,
'killsplayer_7':0,
'killsplayer_8':0,
'killsplayer_9':0,
'killsplayer_10':0,
'level_1':0,
'level_10':0,
'level_2':0,
'level_3':0,
'level_4':0,
'level_5':0,
'level_6':0,
'level_7':0,
'level_8':0,
'level_9':0,
'magicDamageDoneToChampions_1':0,
'magicDamageDoneToChampions_10':0,
'magicDamageDoneToChampions_2':0,
'magicDamageDoneToChampions_3':0,
'magicDamageDoneToChampions_4':0,
'magicDamageDoneToChampions_5':0,
'magicDamageDoneToChampions_6':0,
'magicDamageDoneToChampions_7':0,
'magicDamageDoneToChampions_8':0,
'magicDamageDoneToChampions_9':0,
'matchId':0,
'minionsKilled_1':0,
'minionsKilled_10':0,
'minionsKilled_2':0,
'minionsKilled_3':0,
'minionsKilled_4':0,
'minionsKilled_5':0,
'minionsKilled_6':0,
'minionsKilled_7':0,
'minionsKilled_8':0,
'minionsKilled_9':0,
'physicalDamageDoneToChampions_1':0,
'physicalDamageDoneToChampions_10':0,
'physicalDamageDoneToChampions_2':0,
'physicalDamageDoneToChampions_3':0,
'physicalDamageDoneToChampions_4':0,
'physicalDamageDoneToChampions_5':0,
'physicalDamageDoneToChampions_6':0,
'physicalDamageDoneToChampions_7':0,
'physicalDamageDoneToChampions_8':0,
'physicalDamageDoneToChampions_9':0,
'queueId':0,
'riftherald_team100':0,
'timeEnemySpentControlled_1':0,
'timeEnemySpentControlled_10':0,
'timeEnemySpentControlled_2':0,
'timeEnemySpentControlled_3':0,
'timeEnemySpentControlled_4':0,
'timeEnemySpentControlled_5':0,
'timeEnemySpentControlled_6':0,
'timeEnemySpentControlled_7':0,
'timeEnemySpentControlled_8':0,
'timeEnemySpentControlled_9':0,
'timestamp':0,
'totalDamageDoneToChampions_1':0,
'totalDamageDoneToChampions_10':0,
'totalDamageDoneToChampions_2':0,
'totalDamageDoneToChampions_3':0,
'totalDamageDoneToChampions_4':0,
'totalDamageDoneToChampions_5':0,
'totalDamageDoneToChampions_6':0,
'totalDamageDoneToChampions_7':0,
'totalDamageDoneToChampions_8':0,
'totalDamageDoneToChampions_9':0,
'totalGold_1':0,
'totalGold_10':0,
'totalGold_2':0,
'totalGold_3':0,
'totalGold_4':0,
'totalGold_5':0,
'totalGold_6':0,
'totalGold_7':0,
'totalGold_8':0,
'totalGold_9':0,
'towers_lost_team100':0,
'towers_lost_team200':0,
'trueDamageDoneToChampions_1':0,
'trueDamageDoneToChampions_10':0,
'trueDamageDoneToChampions_2':0,
'trueDamageDoneToChampions_3':0,
'trueDamageDoneToChampions_4':0,
'trueDamageDoneToChampions_5':0,
'trueDamageDoneToChampions_6':0,
'trueDamageDoneToChampions_7':0,
'trueDamageDoneToChampions_8':0,
'trueDamageDoneToChampions_9':0,
'ward_player_1':0,
'ward_player_10':0,
'ward_player_2':0,
'ward_player_3':0,
'ward_player_4':0,
'ward_player_5':0,
'ward_player_6':0,
'ward_player_7':0,
'ward_player_8':0,
'ward_player_9':0,
'waterdragon_team100':0,
'winningTeam':0,
'xp_1':0,
'xp_10':0,
'xp_2':0,
'xp_3':0,
'xp_4':0,
'xp_5':0,
'xp_6':0,
'xp_7':0,
'xp_8':0,
'xp_9':0,
'airdragon_team100':0,
'assistsplayer_7':0,
'chemtechdragon_team100':0,
'earthdragon_team100':0,
'killsplayer_10':0,
'killsplayer_6':0,
'killsplayer_8':0,
'riftherald_team300':0,
'assistsplayer_1':0,
'baron_team100':0,
'earthdragon_team200':0,
'ward_player_0':0}

# %%
d['assistsplayer_10'] = 4

# %%
d
# Out:
# {'assistsplayer_10': 4,
#  'assistsplayer_2': 0,
#  'assistsplayer_3': 0,
#  'assistsplayer_4': 0,
#  'assistsplayer_5': 0,
#  'assistsplayer_8': 0,
#  'assistsplayer_9': 0,
#  'assistsplayer_1': 0,
#  'currentGold_1': 0,
#  'currentGold_10': 0,
#  'currentGold_2': 0,
#  'currentGold_3': 0,
#  'currentGold_4': 0,
#  'currentGold_5': 0,
#  'currentGold_6': 0,
#  'currentGold_7': 0,
#  'currentGold_8': 0,
#  'currentGold_9': 0,
#  'deathsplayer_1': 0,
#  'deathsplayer_10': 0,
#  'deathsplayer_2': 0,
#  'deathsplayer_3': 0,
#  'deathsplayer_4': 0,
#  'deathsplayer_5': 0,
#  'deathsplayer_6': 0,
#  'deathsplayer_7': 0,
#  'deathsplayer_8': 0,
#  'deathsplayer_9': 0,
#  'dragon_team100': 0,
#  'dragon_team200': 0,
#  'firedragon_team100': 0,
#  'firedragon_team200': 0,
#  'gameDuration': 0,
#  'gameEndTimestamp': 0,
#  'gameId': 0,
#  'gameMode': 0,
#  'gameName': 0,
#  'gameStartTimestamp': 0,
#  'gameType': 0,
#  'gameVersion': 0,
#  'goldPerSecond_1': 0,
#  'goldPerSecond_10': 0,
#  'goldPerSecond_2': 0,
#  'goldPerSecond_3': 0,
#  'goldPerSecond_4': 0,
#  'goldPerSecond_5': 0,
#  'goldPerSecond_6': 0,
#  'goldPerSecond_7': 0,
#  'goldPerSecond_8': 0,
#  'goldPerSecond_9': 0,
#  'hextechdragon_team200': 0,
#  'inhibs_lost_team200': 0,
#  'jungleMinionsKilled_1': 0,
#  'jungleMinionsKilled_10': 0,
#  'jungleMinionsKilled_2': 0,
#  'jungleMinionsKilled_3': 0,
#  'jungleMinionsKilled_4': 0,
#  'jungleMinionsKilled_5': 0,
#  'jungleMinionsKilled_6': 0,
#  'jungleMinionsKilled_7': 0,
#  'jungleMinionsKilled_8': 0,
#  'jungleMinionsKilled_9': 0,
#  'killsplayer_1': 0,
#  'killsplayer_2': 0,
#  'killsplayer_3': 0,
#  'killsplayer_4': 0,
#  'killsplayer_5': 0,
#  'killsplayer_6': 0,
#  'killsplayer_7': 0,
#  'killsplayer_8': 0,
#  'killsplayer_9': 0,
#  'killsplayer_10': 0,
#  'level_1': 0,
#  'level_10': 0,
#  'level_2': 0,
#  'level_3': 0,
#  'level_4': 0,
#  'level_5': 0,
#  'level_6': 0,
#  'level_7': 0,
#  'level_8': 0,
#  'level_9': 0,
#  'magicDamageDoneToChampions_1': 0,
#  'magicDamageDoneToChampions_10': 0,
#  'magicDamageDoneToChampions_2': 0,
#  'magicDamageDoneToChampions_3': 0,
#  'magicDamageDoneToChampions_4': 0,
#  'magicDamageDoneToChampions_5': 0,
#  'magicDamageDoneToChampions_6': 0,
#  'magicDamageDoneToChampions_7': 0,
#  'magicDamageDoneToChampions_8': 0,
#  'magicDamageDoneToChampions_9': 0,
#  'matchId': 0,
#  'minionsKilled_1': 0,
#  'minionsKilled_10': 0,
#  'minionsKilled_2': 0,
#  'minionsKilled_3': 0,
#  'minionsKilled_4': 0,
#  'minionsKilled_5': 0,
#  'minionsKilled_6': 0,
#  'minionsKilled_7': 0,
#  'minionsKilled_8': 0,
#  'minionsKilled_9': 0,
#  'physicalDamageDoneToChampions_1': 0,
#  'physicalDamageDoneToChampions_10': 0,
#  'physicalDamageDoneToChampions_2': 0,
#  'physicalDamageDoneToChampions_3': 0,
#  'physicalDamageDoneToChampions_4': 0,
#  'physicalDamageDoneToChampions_5': 0,
#  'physicalDamageDoneToChampions_6': 0,
#  'physicalDamageDoneToChampions_7': 0,
#  'physicalDamageDoneToChampions_8': 0,
#  'physicalDamageDoneToChampions_9': 0,
#  'queueId': 0,
#  'riftherald_team100': 0,
#  'timeEnemySpentControlled_1': 0,
#  'timeEnemySpentControlled_10': 0,
#  'timeEnemySpentControlled_2': 0,
#  'timeEnemySpentControlled_3': 0,
#  'timeEnemySpentControlled_4': 0,
#  'timeEnemySpentControlled_5': 0,
#  'timeEnemySpentControlled_6': 0,
#  'timeEnemySpentControlled_7': 0,
#  'timeEnemySpentControlled_8': 0,
#  'timeEnemySpentControlled_9': 0,
#  'timestamp': 0,
#  'totalDamageDoneToChampions_1': 0,
#  'totalDamageDoneToChampions_10': 0,
#  'totalDamageDoneToChampions_2': 0,
#  'totalDamageDoneToChampions_3': 0,
#  'totalDamageDoneToChampions_4': 0,
#  'totalDamageDoneToChampions_5': 0,
#  'totalDamageDoneToChampions_6': 0,
#  'totalDamageDoneToChampions_7': 0,
#  'totalDamageDoneToChampions_8': 0,
#  'totalDamageDoneToChampions_9': 0,
#  'totalGold_1': 0,
#  'totalGold_10': 0,
#  'totalGold_2': 0,
#  'totalGold_3': 0,
#  'totalGold_4': 0,
#  'totalGold_5': 0,
#  'totalGold_6': 0,
#  'totalGold_7': 0,
#  'totalGold_8': 0,
#  'totalGold_9': 0,
#  'towers_lost_team100': 0,
#  'towers_lost_team200': 0,
#  'trueDamageDoneToChampions_1': 0,
#  'trueDamageDoneToChampions_10': 0,
#  'trueDamageDoneToChampions_2': 0,
#  'trueDamageDoneToChampions_3': 0,
#  'trueDamageDoneToChampions_4': 0,
#  'trueDamageDoneToChampions_5': 0,
#  'trueDamageDoneToChampions_6': 0,
#  'trueDamageDoneToChampions_7': 0,
#  'trueDamageDoneToChampions_8': 0,
#  'trueDamageDoneToChampions_9': 0,
#  'ward_player_1': 0,
#  'ward_player_10': 0,
#  'ward_player_2': 0,
#  'ward_player_3': 0,
#  'ward_player_4': 0,
#  'ward_player_5': 0,
#  'ward_player_6': 0,
#  'ward_player_7': 0,
#  'ward_player_8': 0,
#  'ward_player_9': 0,
#  'waterdragon_team100': 0,
#  'winningTeam': 0,
#  'xp_1': 0,
#  'xp_10': 0,
#  'xp_2': 0,
#  'xp_3': 0,
#  'xp_4': 0,
#  'xp_5': 0,
#  'xp_6': 0,
#  'xp_7': 0,
#  'xp_8': 0,
#  'xp_9': 0,
#  'airdragon_team100': 0,
#  'assistsplayer_7': 0,
#  'chemtechdragon_team100': 0,
#  'earthdragon_team100': 0,
#  'riftherald_team300': 0,
#  'baron_team100': 0,
#  'earthdragon_team200': 0,
#  'ward_player_0': 0}

# %%
d= {'assistsplayer_10':0, 'assistsplayer_2':0, 'assistsplayer_3':0, 'assistsplayer_4':0, 'assistsplayer_5':0, 'assistsplayer_8':0, 'assistsplayer_9':0, 'assistsplayer_1':0, 'currentGold_1':0, 'currentGold_10':0, 'currentGold_2':0, 'currentGold_3':0, 'currentGold_4':0, 'currentGold_5':0, 'currentGold_6':0, 'currentGold_7':0, 'currentGold_8':0, 'currentGold_9':0, 'deathsplayer_1':0, 'deathsplayer_10':0, 'deathsplayer_2':0, 'deathsplayer_3':0, 'deathsplayer_4':0, 'deathsplayer_5':0, 'deathsplayer_6':0, 'deathsplayer_7':0, 'deathsplayer_8':0, 'deathsplayer_9':0, 'dragon_team100':0, 'dragon_team200':0, 'firedragon_team100':0, 'firedragon_team200':0, 'gameDuration':0, 'gameEndTimestamp':0, 'gameId':0, 'gameMode':0, 'gameName':0, 'gameStartTimestamp':0, 'gameType':0, 'gameVersion':0, 'goldPerSecond_1':0, 'goldPerSecond_10':0, 'goldPerSecond_2':0, 'goldPerSecond_3':0, 'goldPerSecond_4':0, 'goldPerSecond_5':0, 'goldPerSecond_6':0, 'goldPerSecond_7':0, 'goldPerSecond_8':0, 'goldPerSecond_9':0, 'hextechdragon_team200':0, 'inhibs_lost_team200':0, 'jungleMinionsKilled_1':0, 'jungleMinionsKilled_10':0, 'jungleMinionsKilled_2':0, 'jungleMinionsKilled_3':0, 'jungleMinionsKilled_4':0, 'jungleMinionsKilled_5':0, 'jungleMinionsKilled_6':0, 'jungleMinionsKilled_7':0, 'jungleMinionsKilled_8':0, 'jungleMinionsKilled_9':0, 'killsplayer_1':0, 'killsplayer_2':0, 'killsplayer_3':0, 'killsplayer_4':0, 'killsplayer_5':0, 'killsplayer_6':0, 'killsplayer_7':0, 'killsplayer_8':0, 'killsplayer_9':0, 'killsplayer_10':0, 'level_1':0, 'level_10':0, 'level_2':0, 'level_3':0, 'level_4':0, 'level_5':0, 'level_6':0, 'level_7':0, 'level_8':0, 'level_9':0, 'magicDamageDoneToChampions_1':0, 'magicDamageDoneToChampions_10':0, 'magicDamageDoneToChampions_2':0, 'magicDamageDoneToChampions_3':0, 'magicDamageDoneToChampions_4':0, 'magicDamageDoneToChampions_5':0, 'magicDamageDoneToChampions_6':0, 'magicDamageDoneToChampions_7':0, 'magicDamageDoneToChampions_8':0, 'magicDamageDoneToChampions_9':0, 'matchId':0, 'minionsKilled_1':0, 'minionsKilled_10':0, 'minionsKilled_2':0, 'minionsKilled_3':0, 'minionsKilled_4':0, 'minionsKilled_5':0, 'minionsKilled_6':0, 'minionsKilled_7':0, 'minionsKilled_8':0, 'minionsKilled_9':0, 'physicalDamageDoneToChampions_1':0, 'physicalDamageDoneToChampions_10':0, 'physicalDamageDoneToChampions_2':0, 'physicalDamageDoneToChampions_3':0, 'physicalDamageDoneToChampions_4':0, 'physicalDamageDoneToChampions_5':0, 'physicalDamageDoneToChampions_6':0, 'physicalDamageDoneToChampions_7':0, 'physicalDamageDoneToChampions_8':0, 'physicalDamageDoneToChampions_9':0, 'queueId':0, 'riftherald_team100':0, 'timeEnemySpentControlled_1':0, 'timeEnemySpentControlled_10':0, 'timeEnemySpentControlled_2':0, 'timeEnemySpentControlled_3':0, 'timeEnemySpentControlled_4':0, 'timeEnemySpentControlled_5':0, 'timeEnemySpentControlled_6':0, 'timeEnemySpentControlled_7':0, 'timeEnemySpentControlled_8':0, 'timeEnemySpentControlled_9':0, 'timestamp':0, 'totalDamageDoneToChampions_1':0, 'totalDamageDoneToChampions_10':0, 'totalDamageDoneToChampions_2':0, 'totalDamageDoneToChampions_3':0, 'totalDamageDoneToChampions_4':0, 'totalDamageDoneToChampions_5':0, 'totalDamageDoneToChampions_6':0, 'totalDamageDoneToChampions_7':0, 'totalDamageDoneToChampions_8':0, 'totalDamageDoneToChampions_9':0, 'totalGold_1':0, 'totalGold_10':0, 'totalGold_2':0, 'totalGold_3':0, 'totalGold_4':0, 'totalGold_5':0, 'totalGold_6':0, 'totalGold_7':0, 'totalGold_8':0, 'totalGold_9':0, 'towers_lost_team100':0, 'towers_lost_team200':0, 'trueDamageDoneToChampions_1':0, 'trueDamageDoneToChampions_10':0, 'trueDamageDoneToChampions_2':0, 'trueDamageDoneToChampions_3':0, 'trueDamageDoneToChampions_4':0, 'trueDamageDoneToChampions_5':0, 'trueDamageDoneToChampions_6':0, 'trueDamageDoneToChampions_7':0, 'trueDamageDoneToChampions_8':0, 'trueDamageDoneToChampions_9':0, 'ward_player_1':0, 'ward_player_10':0, 'ward_player_2':0, 'ward_player_3':0, 'ward_player_4':0, 'ward_player_5':0, 'ward_player_6':0, 'ward_player_7':0, 'ward_player_8':0, 'ward_player_9':0, 'waterdragon_team100':0, 'winningTeam':0, 'xp_1':0, 'xp_10':0, 'xp_2':0, 'xp_3':0, 'xp_4':0, 'xp_5':0, 'xp_6':0, 'xp_7':0, 'xp_8':0, 'xp_9':0, 'airdragon_team100':0, 'assistsplayer_7':0, 'chemtechdragon_team100':0, 'earthdragon_team100':0, 'killsplayer_10':0, 'killsplayer_6':0, 'killsplayer_8':0, 'riftherald_team300':0, 'assistsplayer_1':0, 'baron_team100':0, 'earthdragon_team200':0, 'ward_player_0':0}
